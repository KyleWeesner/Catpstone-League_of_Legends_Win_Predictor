# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

import requests
from riotwatcher import LolWatcher, ApiError
import json

# %%
# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = list((get_keys('/Users/weesn/Documents/Flatiron/secrets.json')).values())[0]

# %%
lol_watcher = LolWatcher(f'{api_keys}')
my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'KyleWeez')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise
# Out:
# {'id': 'sxAViHUpUFO1U0yayOWQHuWFBfvQ4iYtUa3dMcxag3UK3eQ', 'accountId': 'TkRmi54Sa-lOuySeCliJQ8BTBRtvAY5gBHkkGJeL9gSs3MQ', 'puuid': 'f9jL5C1IrczsbmdVUxcv8ZcrkWqlpy_6YRP3VgvVNhUIM64Ml-Bd1PFcNM0_nACpWkumdLuj6Ax-gA', 'name': 'KyleWeez', 'profileIconId': 1388, 'revisionDate': 1652764501000, 'summonerLevel': 374}
# [{'leagueId': '371f2307-b230-4972-be37-9647e7a277cf', 'queueType': 'RANKED_FLEX_SR', 'tier': 'GOLD', 'rank': 'IV', 'summonerId': 'sxAViHUpUFO1U0yayOWQHuWFBfvQ4iYtUa3dMcxag3UK3eQ', 'summonerName': 'KyleWeez', 'leaguePoints': 13, 'wins': 27, 'losses': 18, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}, {'leagueId': '0d0cb7a5-3699-4ffb-b246-2a37ceba3e52', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'PLATINUM', 'rank': 'III', 'summonerId': 'sxAViHUpUFO1U0yayOWQHuWFBfvQ4iYtUa3dMcxag3UK3eQ', 'summonerName': 'KyleWeez', 'leaguePoints': 16, 'wins': 44, 'losses': 31, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}]
# {'type': 'champion', 'format': 'standAloneComplex', 'version': '12.9.1', 'data': {'Aatrox': {'version': '12.9.1', 'id': 'Aatrox', 'key': '266', 'name': 'Aatrox', 'title': 'the Darkin Blade', 'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...', 'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}, 'image': {'full': 'Aatrox.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 0, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Fighter', 'Tank'], 'partype': 'Blood Well', 'stats': {'hp': 580, 'hpperlevel': 90, 'mp': 0, 'mpperlevel': 0, 'movespeed': 345, 'armor': 38, 'armorperlevel': 3.25, 'spellblock': 32, 'spellblockperlevel': 1.25, 'attackrange': 175, 'hpregen': 3, 'hpregenperlevel': 1, 'mpregen': 0, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 60, 'attackdamageperlevel': 5, 'attackspeedperlevel': 2.5, 'attackspeed': 0.651}}, 'Ahri': {'version': '12.9.1', 'id': 'Ahri', 'key': '103', 'name': 'Ahri', 'title': 'the Nine-Tailed Fox', 'blurb': 'Innately connected to the latent power of Runeterra, Ahri is a vastaya who can reshape magic into orbs of raw energy. She revels in toying with her prey by manipulating their emotions before devouring their life essence. Despite her predatory nature...', 'info': {'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 5}, 'image': {'full': 'Ahri.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 48, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Mage', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 500, 'hpperlevel': 82, 'mp': 418, 'mpperlevel': 25, 'movespeed': 330, 'armor': 18, 'armorperlevel': 3.5, 'spellblock': 30, 'spellblockperlevel': 0.5, 'attackrange': 550, 'hpregen': 2.5, 'hpregenperlevel': 0.6, 'mpregen': 8, 'mpregenperlevel': 0.8, 'crit': 0, 'critperlevel': 0, 'attackdamage': 53, 'attackdamageperlevel': 3, 'attackspeedperlevel': 2, 'attackspeed': 0.668}}, 'Akali': {'version': '12.9.1', 'id': 'Akali', 'key': '84', 'name': 'Akali', 'title': 'the Rogue Assassin', 'blurb': 'Abandoning the Kinkou Order and her title of the Fist of Shadow, Akali now strikes alone, ready to be the deadly weapon her people need. Though she holds onto all she learned from her master Shen, she has pledged to defend Ionia from its enemies, one...', 'info': {'attack': 5, 'defense': 3, 'magic': 8, 'difficulty': 7}, 'image': {'full': 'Akali.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 96, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Assassin'], 'partype': 'Energy', 'stats': {'hp': 500, 'hpperlevel': 105, 'mp': 200, 'mpperlevel': 0, 'movespeed': 345, 'armor': 23, 'armorperlevel': 3.5, 'spellblock': 37, 'spellblockperlevel': 1.25, 'attackrange': 125, 'hpregen': 9, 'hpregenperlevel': 0.9, 'mpregen': 50, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 62, 'attackdamageperlevel': 3.3, 'attackspeedperlevel': 3.2, 'attackspeed': 0.625}}, 'Akshan': {'version': '12.9.1', 'id': 'Akshan', 'key': '166', 'name': 'Akshan', 'title': 'the Rogue Sentinel', 'blurb': 'Raising an eyebrow in the face of danger, Akshan fights evil with dashing charisma, righteous vengeance, and a conspicuous lack of shirts. He is highly skilled in the art of stealth combat, able to evade the eyes of his enemies and reappear when they...', 'info': {'attack': 0, 'defense': 0, 'magic': 0, 'difficulty': 0}, 'image': {'full': 'Akshan.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 144, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Marksman', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 560, 'hpperlevel': 90, 'mp': 350, 'mpperlevel': 40, 'movespeed': 330, 'armor': 26, 'armorperlevel': 3, 'spellblock': 30, 'spellblockperlevel': 0.5, 'attackrange': 500, 'hpregen': 3.75, 'hpregenperlevel': 0.65, 'mpregen': 8.175, 'mpregenperlevel': 0.7, 'crit': 0, 'critperlevel': 0, 'attackdamage': 52, 'attackd ...
# Summoner with that ridiculous name not found.

# %% [markdown]
# # Test run.  Getting wanted DataFrame using 10  players from challenger

# %%
player_region= 'NA1'.lower()
queue_type= 'RANKED_SOLO_5x5' 
challenger_ladder= lol_watcher.league.challenger_by_queue(region= player_region, 
                                                          queue=queue_type)
challenger = pd.DataFrame(challenger_ladder)

# %%
challenger_players= pd.DataFrame.from_dict(challenger_ladder['entries'])
challenger_info_df = pd.merge(challenger,challenger_players, left_index=True, right_index=True)
challenger_info_df['total_games'] = challenger_info_df['wins'] + challenger_info_df['losses']
challenger_info_df
# Out:
#            tier                              leagueId            queue  \
# 0    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 1    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 2    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 3    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 4    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# ..          ...                                   ...              ...
# 295  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 296  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 297  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 298  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 299  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
#
#                  name                                            entries  \
# 0    Swain's Villains  {'summonerId': 'v5U_LC3XbeVF0LZVAIpjnaM1hQ-OW5...
# 1    Swain's Villains  {'summonerId': 'q1pi8kvi4AM4n2xL33FABJupg335lT...
# 2    Swain's Villains  {'summonerId': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjU...
# 3    Swain's Villains  {'summonerId': '9qBSKLeuuYkwpTDq5PPTWPQrymZsQX...
# 4    Swain's Villains  {'summonerId': '7KJ2BEcHvArWCLAVd4ahB5TJHjdKFS...
# ..                ...                                                ...
# 295  Swain's Villains  {'summonerId': 'sgKfxe6Fdqbwuy0pJpdTlm-RrOm5wh...
# 296  Swain's Villains  {'summonerId': 'fpq5jA2wKU4OzNntf38ELRtShOV7kN...
# 297  Swain's Villains  {'summonerId': 'C3LkqvlGsJOXYiax6Kjgy_FsabEmjX...
# 298  Swain's Villains  {'summonerId': 'Uu0WabTQd4onpn9UXL0NXO10Lln2-A...
# 299  Swain's Villains  {'summonerId': 'S72odS8SZq1LplLT4Lu8JaK4MfwI5F...
#
#                                             summonerId    summonerName  \
# 0    v5U_LC3XbeVF0LZVAIpjnaM1hQ-OW5RmR9_Wbgn-CJO6ll...         hao de
# 1      q1pi8kvi4AM4n2xL33FABJupg335lTg191clfgA32HGLmAs       rockonhi5
# 2     yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb          Airren
# 3         9qBSKLeuuYkwpTDq5PPTWPQrymZsQXIqewzi430eW4sw           Dèity
# 4      7KJ2BEcHvArWCLAVd4ahB5TJHjdKFSXBj2t6gQtWKOPjN70             t d
# ..                                                 ...             ...
# 295    sgKfxe6Fdqbwuy0pJpdTlm-RrOm5wh4ayZ4RYo0XEzjgvJI        RobbyBob
# 296  fpq5jA2wKU4OzNntf38ELRtShOV7kNPufqafvrJoOCPCnL...           Minui
# 297   C3LkqvlGsJOXYiax6Kjgy_FsabEmjXA3eo36tmYm-c5SYIE3           aknid
# 298   Uu0WabTQd4onpn9UXL0NXO10Lln2-Avx8pbTc_-dKSGtQ4mc       JohnnyCap
# 299    S72odS8SZq1LplLT4Lu8JaK4MfwI5FTGAVhBKFdsI5h-zXw  NøticeMeSenpai
#
#      leaguePoints rank  wins  losses  veteran  inactive  freshBlood  \
# 0             829    I   199     181     True     False       False
# 1             810    I   266     238     True     False       False
# 2             837    I   203     179    False     False       False
# 3            1166    I   308     268     True     False       False
# 4             952    I   326     293    False     False       False
# ..            ...  ...   ...     ...      ...       ...         ...
# 295          1061    I   130      89    False     False       False
# 296           846    I   173     144    False     False       False
# 297           836    I   262     239    False     False       False
# 298           908    I   138     110    False     False       False
# 299          1045    I   174     141     True     False       False
#
#      hotStreak  total_games
# 0        False          380
# 1         True          504
# 2         True          382
# 3        False          576
# 4        False          619
# ..         ...          ...
# 295       True          219
# 296      False          317
# 297      False          501
# 298      False          248
# 299      False          315
#
# [300 rows x 16 columns]

# %%
players10_challenger = challenger_info_df.head(10)
players10_challenger
# Out:
#          tier                              leagueId            queue  \
# 0  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 1  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 2  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 3  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 4  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 5  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 6  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 7  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 8  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 9  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
#
#                name                                            entries  \
# 0  Swain's Villains  {'summonerId': 'v5U_LC3XbeVF0LZVAIpjnaM1hQ-OW5...
# 1  Swain's Villains  {'summonerId': 'q1pi8kvi4AM4n2xL33FABJupg335lT...
# 2  Swain's Villains  {'summonerId': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjU...
# 3  Swain's Villains  {'summonerId': '9qBSKLeuuYkwpTDq5PPTWPQrymZsQX...
# 4  Swain's Villains  {'summonerId': '7KJ2BEcHvArWCLAVd4ahB5TJHjdKFS...
# 5  Swain's Villains  {'summonerId': 'rXoejkZ3pifMeTgGR-BiCWTLVnqwQe...
# 6  Swain's Villains  {'summonerId': 'h18Pt1LJwoc1ioUk8ht3X-3kpq2G1j...
# 7  Swain's Villains  {'summonerId': 'uPYzBWlk7pfCJwk4TKT86vnilDhB5t...
# 8  Swain's Villains  {'summonerId': 'dgMcpMRc2quDh4657UI-86sWRPKeHw...
# 9  Swain's Villains  {'summonerId': '7LP6-nUJy_gfLiGOlyb_h7JGsi27TT...
#
#                                           summonerId  summonerName  \
# 0  v5U_LC3XbeVF0LZVAIpjnaM1hQ-OW5RmR9_Wbgn-CJO6ll...       hao de
# 1    q1pi8kvi4AM4n2xL33FABJupg335lTg191clfgA32HGLmAs     rockonhi5
# 2   yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb        Airren
# 3       9qBSKLeuuYkwpTDq5PPTWPQrymZsQXIqewzi430eW4sw         Dèity
# 4    7KJ2BEcHvArWCLAVd4ahB5TJHjdKFSXBj2t6gQtWKOPjN70           t d
# 5       rXoejkZ3pifMeTgGR-BiCWTLVnqwQetwKaJ7suBvFVUC   Ablazeolive
# 6    h18Pt1LJwoc1ioUk8ht3X-3kpq2G1jiEg3cvoUEBT2_Ou44  Wynncraftian
# 7  uPYzBWlk7pfCJwk4TKT86vnilDhB5t9nx7L94lely714w1...           آدم
# 8   dgMcpMRc2quDh4657UI-86sWRPKeHwipqzYisryWsCab8E6c     ScrubNoob
# 9    7LP6-nUJy_gfLiGOlyb_h7JGsi27TTLa41ahtL4VJlgh2_8    vx  pwyezi
#
#    leaguePoints rank  wins  losses  veteran  inactive  freshBlood  hotStreak  \
# 0           829    I   199     181     True     False       False      False
# 1           810    I   266     238     True     False       False       True
# 2           837    I   203     179    False     False       False       True
# 3          1166    I   308     268     True     False       False      False
# 4           952    I   326     293    False     False       False      False
# 5          1496    I   192     141     True     False       False      False
# 6           804    I   166     142    False     False        True       True
# 7           991    I   200     169     True     False       False      False
# 8          1055    I   212     175     True     False       False      False
# 9           822    I   219     187    False     False       False      False
#
#    total_games
# 0          380
# 1          504
# 2          382
# 3          576
# 4          619
# 5          333
# 6          308
# 7          369
# 8          387
# 9          406

# %%
players10_challenger.summonerName
# Out:
# 0         hao de
# 1       rockonhi5
# 2          Airren
# 3           Dèity
# 4             t d
# 5     Ablazeolive
# 6    Wynncraftian
# 7             آدم
# 8       ScrubNoob
# 9      vx  pwyezi
# Name: summonerName, dtype: object

# %%
player_name= players10_challenger.summonerName
player_region= 'NA1'.lower()
player_routing= 'americas'
player_info = []

for player in player_name:
    player_info.append(lol_watcher.summoner.by_name(player_region, player))
player_info
# Out:
# [{'id': 'AYIb8-DIWJgD9zDwTRZIyH1IabNS3pUa90boTZ-nspXgJQeMpW8F8pOG7g',
#   'accountId': 'LNNsne8DmouQBdJ37hw2fZggFHScf1YKNefoqYwsIGRbi5nvD49y42ud',
#   'puuid': '7PWpCc8TFrFSrNtaw7TKnmCDMavdXRFaGrlSb_lJAZWvTR0C08P641cyE1lcNWqcRFAov5D17ubx_Q',
#   'name': 'hao de',
#   'profileIconId': 29,
#   'revisionDate': 1652783532000,
#   'summonerLevel': 1},
#  {'id': 'q1pi8kvi4AM4n2xL33FABJupg335lTg191clfgA32HGLmAs',
#   'accountId': '8dbANXxa_VY8zsVbEhEErkHoAC9ddGBn9XljwvNr4WpaFA',
#   'puuid': '9KBxzb8kd3kMaxxqs0Bg86MVurtKaByuJG8orFbrLX8b7IxLnC0oo1Eh_gCyy8Kcv_742gfKaNWMvg',
#   'name': 'rockonhi5',
#   'profileIconId': 5270,
#   'revisionDate': 1652843383000,
#   'summonerLevel': 323},
#  {'id': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb',
#   'accountId': 'zd3xHtQ8jehHZpCYw3RdU9hgu-3Qbkstv3GA1hCiGzbfVFmAj_HL28Wk',
#   'puuid': 'Js54dBF07DBtQtIVABk-8AI9RRt1H7hgAKHyATGcTowFseQhRzJqt__PPsEGC893MIqwPR4Yp3bINg',
#   'name': 'Airren',
#   'profileIconId': 5314,
#   'revisionDate': 1652638644000,
#   'summonerLevel': 167},
#  {'id': '9qBSKLeuuYkwpTDq5PPTWPQrymZsQXIqewzi430eW4sw',
#   'accountId': 'SyeYYOdqnuHD0tUrKnAaRjySBtkegxHwWKL7zOAdt9U_Og',
#   'puuid': 'pFN5qLPC3BBz2ih8vzhfxTKMWciEq-lUQH2Amfy5_AyYBEgx18tJBqiPyKPwp9Zf23276aY_YwnnRw',
#   'name': 'Dèity',
#   'profileIconId': 3890,
#   'revisionDate': 1652858925000,
#   'summonerLevel': 291},
#  {'id': '7KJ2BEcHvArWCLAVd4ahB5TJHjdKFSXBj2t6gQtWKOPjN70',
#   'accountId': '9WqgWr6zvHdzBqSOveUHQk6zIfH1JIjYRwefapHpm_EZ-Zg',
#   'puuid': 'vvLc4NlhyXiDJSZMqTgysFGIbk95Tfz5n-G89Rbh4GYNaGNNmS0asoq0pQrY8ecQm8ND_SrtIJKpQA',
#   'name': 't d',
#   'profileIconId': 25,
#   'revisionDate': 1652560282185,
#   'summonerLevel': 646},
#  {'id': 'rXoejkZ3pifMeTgGR-BiCWTLVnqwQetwKaJ7suBvFVUC',
#   'accountId': 'qRiJXNQ8fEy21F7gAcex64I7SllcpYIA4mJuo8mWIJo',
#   'puuid': 'M2s8SZgZ7Pmcld4q7eDmzBOP6NFFsMu9oGUpwtwb07o1STvxGpnWwGDLhJZphhRLIL3fSiObJPW0Bw',
#   'name': 'Ablazeolive',
#   'profileIconId': 23,
#   'revisionDate': 1652546442000,
#   'summonerLevel': 350},
#  {'id': 'h18Pt1LJwoc1ioUk8ht3X-3kpq2G1jiEg3cvoUEBT2_Ou44',
#   'accountId': 'fKFaaky6UX1ZA8nFm5LdmCIVRVjRWTMXTGQQ6l286H14rz0',
#   'puuid': 'zB309clhi8o20kVbIjfgTLlw260ORRd9bZWS5RNSzAjdomTMGfx3P8csrsQT7LqG8hcuy2On5H_uLQ',
#   'name': 'Wynncraftian',
#   'profileIconId': 18,
#   'revisionDate': 1652744171000,
#   'summonerLevel': 547},
#  {'id': 'uPYzBWlk7pfCJwk4TKT86vnilDhB5t9nx7L94lely714w1d0DN93ipDqVA',
#   'accountId': 'n189RECBWPRCts3Cdg7teh_MuzyiXZu0ei1PFKajpuHXaPMdD13Oq7f_',
#   'puuid': 'MjBB1HQapZEYAL7g5rLCRRbvF2OLjXSMwk9cOODTqw2T3uCUsn2oF0MTpd8ZyKFEgmN-cT0Ph0orzg',
#   'name': 'آدم',
#   'profileIconId': 983,
#   'revisionDate': 1652650080198,
#   'summonerLevel': 366},
#  {'id': 'dgMcpMRc2quDh4657UI-86sWRPKeHwipqzYisryWsCab8E6c',
#   'accountId': 'gHiQt0pFcF6iNQW9FMoEW6XCkc5zdo688PapnuZEK6F8qrXdhzbtOwZ4',
#   'puuid': 'nwL3-HOXSpT4u1su-atzJuog1t0fcGcoBaOD_mJSHNM6CB7KCBx4RJSVO3Zw6Qu-_w0urv2KBKJ4vw',
#   'name': 'ScrubNoob',
#   'profileIconId': 5320,
#   'revisionDate': 1652566703000,
#   'summonerLevel': 167},
#  {'id': '7LP6-nUJy_gfLiGOlyb_h7JGsi27TTLa41ahtL4VJlgh2_8',
#   'accountId': 'TYm_YJca-CrreKt6I8Z-nepTpkEJKdWphCt3AIoeM8YYS9k',
#   'puuid': '4tWEjGoPw_db3cnUB-6ruwzuSqVqO_opIco9xh767Jm3ZM5ZDFSPjo6anRf04FarXAP2lid02vxMUw',
#   'name': 'vx  pwyezi',
#   'profileIconId': 5230,
#   'revisionDate': 1652818093000,
#   'summonerLevel': 402}]

# %%
players10_challenger
# Out:
#          tier                              leagueId            queue  \
# 0  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 1  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 2  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 3  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 4  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 5  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 6  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 7  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 8  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 9  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
#
#                name                                            entries  \
# 0  Swain's Villains  {'summonerId': 'v5U_LC3XbeVF0LZVAIpjnaM1hQ-OW5...
# 1  Swain's Villains  {'summonerId': 'q1pi8kvi4AM4n2xL33FABJupg335lT...
# 2  Swain's Villains  {'summonerId': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjU...
# 3  Swain's Villains  {'summonerId': '9qBSKLeuuYkwpTDq5PPTWPQrymZsQX...
# 4  Swain's Villains  {'summonerId': '7KJ2BEcHvArWCLAVd4ahB5TJHjdKFS...
# 5  Swain's Villains  {'summonerId': 'rXoejkZ3pifMeTgGR-BiCWTLVnqwQe...
# 6  Swain's Villains  {'summonerId': 'h18Pt1LJwoc1ioUk8ht3X-3kpq2G1j...
# 7  Swain's Villains  {'summonerId': 'uPYzBWlk7pfCJwk4TKT86vnilDhB5t...
# 8  Swain's Villains  {'summonerId': 'dgMcpMRc2quDh4657UI-86sWRPKeHw...
# 9  Swain's Villains  {'summonerId': '7LP6-nUJy_gfLiGOlyb_h7JGsi27TT...
#
#                                           summonerId  summonerName  \
# 0  v5U_LC3XbeVF0LZVAIpjnaM1hQ-OW5RmR9_Wbgn-CJO6ll...       hao de
# 1    q1pi8kvi4AM4n2xL33FABJupg335lTg191clfgA32HGLmAs     rockonhi5
# 2   yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb        Airren
# 3       9qBSKLeuuYkwpTDq5PPTWPQrymZsQXIqewzi430eW4sw         Dèity
# 4    7KJ2BEcHvArWCLAVd4ahB5TJHjdKFSXBj2t6gQtWKOPjN70           t d
# 5       rXoejkZ3pifMeTgGR-BiCWTLVnqwQetwKaJ7suBvFVUC   Ablazeolive
# 6    h18Pt1LJwoc1ioUk8ht3X-3kpq2G1jiEg3cvoUEBT2_Ou44  Wynncraftian
# 7  uPYzBWlk7pfCJwk4TKT86vnilDhB5t9nx7L94lely714w1...           آدم
# 8   dgMcpMRc2quDh4657UI-86sWRPKeHwipqzYisryWsCab8E6c     ScrubNoob
# 9    7LP6-nUJy_gfLiGOlyb_h7JGsi27TTLa41ahtL4VJlgh2_8    vx  pwyezi
#
#    leaguePoints rank  wins  losses  veteran  inactive  freshBlood  hotStreak  \
# 0           829    I   199     181     True     False       False      False
# 1           810    I   266     238     True     False       False       True
# 2           837    I   203     179    False     False       False       True
# 3          1166    I   308     268     True     False       False      False
# 4           952    I   326     293    False     False       False      False
# 5          1496    I   192     141     True     False       False      False
# 6           804    I   166     142    False     False        True       True
# 7           991    I   200     169     True     False       False      False
# 8          1055    I   212     175     True     False       False      False
# 9           822    I   219     187    False     False       False      False
#
#    total_games
# 0          380
# 1          504
# 2          382
# 3          576
# 4          619
# 5          333
# 6          308
# 7          369
# 8          387
# 9          406

# %%
players10_challenger.total_games.min()
# Out:
# 308

# %%
players10_challenger.total_games[players10_challenger.summonerName == player_name]
# Out:
# 0    380
# 1    504
# 2    382
# 3    576
# 4    619
# 5    333
# 6    308
# 7    369
# 8    387
# 9    406
# Name: total_games, dtype: int64

# %% [markdown]
# # getting matchId

# %%
player_name= 'EricZYang'
player_region= 'NA1'.lower() #[BR1, EUN1, EUW1, JP1, KR, LA1, LA2, NA1, OC1, TR1, RU]  
player_routing= 'americas'
summoner= lol_watcher.summoner.by_name(player_region, player_name)
match_history= lol_watcher.match.matchlist_by_puuid(region= player_routing, puuid= summoner['puuid'],
                                                    queue= 420, 
                                                    start=0, count= 100) #this wrapper max count is 100

# %%
player_name= players10_challenger.summonerName
player_region= 'NA1'.lower()
player_routing= 'americas'
match_history = []

for player in player_name:
    summoner= lol_watcher.summoner.by_name(player_region, player)
    for games in players10_challenger.total_games:
        match_history.append(lol_watcher.match.matchlist_by_puuid(region= player_routing, puuid= summoner['puuid'],
                                                        queue= 420, 
                                                        start=0, count= 100))

# %% [markdown]
# If i want to grab all of the games.  look into try except!!! if cant figure out ask saad

# %%
len(match_history)
# Out:
# 100

# %%
all_matchIDs = sum(match_history, [])
all_matchIDs
# Out:
# ['NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  'NA1_4311225239',
#  'NA1_4310105671',
#  'NA1_4310062668',
#  'NA1_4309966080',
#  'NA1_4309952136',
#  'NA1_4308872421',
#  'NA1_4308421422',
#  'NA1_4308327955',
#  'NA1_4308313583',
#  'NA1_4308303201',
#  'NA1_4307684469',
#  'NA1_4307547922',
#  'NA1_4307583843',
#  'NA1_4307528688',
#  'NA1_4307505357',
#  'NA1_4307190911',
#  'NA1_4306215690',
#  'NA1_4306190760',
#  'NA1_4306128065',
#  'NA1_4306154292',
#  'NA1_4305664703',
#  'NA1_4305575464',
#  'NA1_4305190634',
#  'NA1_4305135910',
#  'NA1_4305104439',
#  'NA1_4304239357',
#  'NA1_4303212281',
#  'NA1_4300560943',
#  'NA1_4300497074',
#  'NA1_4300481975',
#  'NA1_4300417825',
#  'NA1_4300432105',
#  'NA1_4299272756',
#  'NA1_4299213715',
#  'NA1_4299197668',
#  'NA1_4299087814',
#  'NA1_4299080045',
#  'NA1_4299040276',
#  'NA1_4298553927',
#  'NA1_4298515391',
#  'NA1_4298372826',
#  'NA1_4298346616',
#  'NA1_4298332034',
#  'NA1_4298231243',
#  'NA1_4298178574',
#  'NA1_4297636134',
#  'NA1_4297592009',
#  'NA1_4297557307',
#  'NA1_4297095646',
#  'NA1_4297093140',
#  'NA1_4296662359',
#  'NA1_4296502305',
#  'NA1_4296309623',
#  'NA1_4296336662',
#  'NA1_4296295462',
#  'NA1_4296313000',
#  'NA1_4295948803',
#  'NA1_4295666138',
#  'NA1_4295671367',
#  'NA1_4295579264',
#  'NA1_4295576624',
#  'NA1_4295611687',
#  'NA1_4295524909',
#  'NA1_4295541953',
#  'NA1_4294279492',
#  'NA1_4292213391',
#  'NA1_4291497511',
#  'NA1_4291483797',
#  'NA1_4291231113',
#  'NA1_4290813922',
#  'NA1_4290766654',
#  'NA1_4290709464',
#  'NA1_4288832466',
#  'NA1_4281511331',
#  'NA1_4279335421',
#  'NA1_4279332155',
#  'NA1_4277905202',
#  'NA1_4277618662',
#  'NA1_4277366024',
#  'NA1_4277399922',
#  'NA1_4277343992',
#  'NA1_4277259418',
#  'NA1_4277272588',
#  'NA1_4275668501',
#  'NA1_4275672528',
#  'NA1_4275214886',
#  'NA1_4275007602',
#  'NA1_4274986472',
#  'NA1_4275014395',
#  'NA1_4274660944',
#  'NA1_4270528217',
#  'NA1_4270070804',
#  'NA1_4269381221',
#  'NA1_4269354434',
#  'NA1_4269148419',
#  'NA1_4269185171',
#  'NA1_4268640148',
#  'NA1_4268067874',
#  'NA1_4268033710',
#  'NA1_4268040187',
#  ...]

# %%
len(all_matchIDs)
# Out:
# 9000

# %%
len(set(all_matchIDs))
# Out:
# 874

# %%
unique_matchIDs = list(set(all_matchIDs))
unique_matchIDs
# Out:
# ['NA1_4308064965',
#  'NA1_4302000078',
#  'NA1_4290709464',
#  'NA1_4295524909',
#  'NA1_4310762485',
#  'NA1_4303855680',
#  'NA1_4285261876',
#  'NA1_4302795858',
#  'NA1_4312624321',
#  'NA1_4311271602',
#  'NA1_4308399822',
#  'NA1_4307841005',
#  'NA1_4298939186',
#  'NA1_4281458083',
#  'NA1_4255452343',
#  'NA1_4269381221',
#  'NA1_4311837990',
#  'NA1_4291492316',
#  'NA1_4308313583',
#  'NA1_4301208379',
#  'NA1_4299571420',
#  'NA1_4288832466',
#  'NA1_4306609319',
#  'NA1_4304797486',
#  'NA1_4300497074',
#  'NA1_4264403742',
#  'NA1_4270192422',
#  'NA1_4301056170',
#  'NA1_4287103657',
#  'NA1_4267089255',
#  'NA1_4248746436',
#  'NA1_4302874061',
#  'NA1_4298553927',
#  'NA1_4272593257',
#  'NA1_4301040957',
#  'NA1_4306128065',
#  'NA1_4284289598',
#  'NA1_4292816616',
#  'NA1_4299119870',
#  'NA1_4293342061',
#  'NA1_4298943992',
#  'NA1_4312911602',
#  'NA1_4278025343',
#  'NA1_4303598759',
#  'NA1_4267130938',
#  'NA1_4287765881',
#  'NA1_4312880604',
#  'NA1_4270344895',
#  'NA1_4302730334',
#  'NA1_4295948803',
#  'NA1_4301069555',
#  'NA1_4303183995',
#  'NA1_4284442994',
#  'NA1_4312204872',
#  'NA1_4310801875',
#  'NA1_4311084305',
#  'NA1_4312207541',
#  'NA1_4307785637',
#  'NA1_4305644836',
#  'NA1_4298894680',
#  'NA1_4287727002',
#  'NA1_4285312184',
#  'NA1_4300168414',
#  'NA1_4291436958',
#  'NA1_4300481975',
#  'NA1_4277297050',
#  'NA1_4285387983',
#  'NA1_4268640148',
#  'NA1_4284414352',
#  'NA1_4277886083',
#  'NA1_4285434783',
#  'NA1_4302852602',
#  'NA1_4242495844',
#  'NA1_4283413967',
#  'NA1_4282378094',
#  'NA1_4288321519',
#  'NA1_4287101000',
#  'NA1_4287640327',
#  'NA1_4270429289',
#  'NA1_4305664703',
#  'NA1_4265887430',
#  'NA1_4290813922',
#  'NA1_4249790461',
#  'NA1_4264617375',
#  'NA1_4290678512',
#  'NA1_4310105671',
#  'NA1_4277259418',
#  'NA1_4309966080',
#  'NA1_4252913877',
#  'NA1_4303284570',
#  'NA1_4299267960',
#  'NA1_4311483344',
#  'NA1_4311604444',
#  'NA1_4269354434',
#  'NA1_4310106583',
#  'NA1_4285683130',
#  'NA1_4295666138',
#  'NA1_4259501920',
#  'NA1_4258946708',
#  'NA1_4279807800',
#  'NA1_4300591511',
#  'NA1_4305933831',
#  'NA1_4285367089',
#  'NA1_4295649079',
#  'NA1_4301551971',
#  'NA1_4311330175',
#  'NA1_4266622625',
#  'NA1_4303643886',
#  'NA1_4312904894',
#  'NA1_4279438829',
#  'NA1_4310099722',
#  'NA1_4283349804',
#  'NA1_4302943046',
#  'NA1_4280744427',
#  'NA1_4267621562',
#  'NA1_4277425458',
#  'NA1_4280732091',
#  'NA1_4288482404',
#  'NA1_4308451709',
#  'NA1_4279861649',
#  'NA1_4306154292',
#  'NA1_4275842881',
#  'NA1_4300729879',
#  'NA1_4306215690',
#  'NA1_4305918120',
#  'NA1_4277848828',
#  'NA1_4307886370',
#  'NA1_4279335421',
#  'NA1_4249896610',
#  'NA1_4277399922',
#  'NA1_4301257098',
#  'NA1_4281754450',
#  'NA1_4270204885',
#  'NA1_4296498581',
#  'NA1_4300363048',
#  'NA1_4275965072',
#  'NA1_4256645942',
#  'NA1_4292162398',
#  'NA1_4309608598',
#  'NA1_4257541122',
#  'NA1_4312585636',
#  'NA1_4270600413',
#  'NA1_4307495882',
#  'NA1_4302661823',
#  'NA1_4277272588',
#  'NA1_4293610644',
#  'NA1_4257717638',
#  'NA1_4260377127',
#  'NA1_4252837484',
#  'NA1_4270625736',
#  'NA1_4300502231',
#  'NA1_4270987675',
#  'NA1_4264625682',
#  'NA1_4288970276',
#  'NA1_4279810688',
#  'NA1_4265055916',
#  'NA1_4295611687',
#  'NA1_4298991862',
#  'NA1_4294327353',
#  'NA1_4295541953',
#  'NA1_4275271670',
#  'NA1_4283202002',
#  'NA1_4268392605',
#  'NA1_4312508907',
#  'NA1_4311034334',
#  'NA1_4278150059',
#  'NA1_4280383167',
#  'NA1_4308525501',
#  'NA1_4311026836',
#  'NA1_4291443232',
#  'NA1_4263486861',
#  'NA1_4264378469',
#  'NA1_4264026182',
#  'NA1_4299207412']

# %%
# [ID.replace('NA1_','') for ID in unique_matchIDs]

# %% [markdown]
# # getting timeline json for one match

# %%
timeline_data = lol_watcher.match.timeline_by_match(region= player_routing, match_id= unique_matchIDs[0])

# %%
pd.DataFrame(timeline_data)
# Out:
#                                                         metadata  \
# dataVersion                                                    2
# matchId                                           NA1_4308064965
# participants   [n0ErYPWPKNzsd0C1hRRRp8nh9nqLjaHRkL4nB0NqbqTVa...
# frameInterval                                                NaN
# frames                                                       NaN
# gameId                                                       NaN
#
#                                                             info
# dataVersion                                                  NaN
# matchId                                                      NaN
# participants   [{'participantId': 1, 'puuid': 'n0ErYPWPKNzsd0...
# frameInterval                                              60000
# frames         [{'events': [{'realTimestamp': 1652581976804, ...
# gameId                                                4308064965

# %%
pd.DataFrame(timeline_data)['info'][2]
# Out:
# [{'participantId': 1,
#   'puuid': 'n0ErYPWPKNzsd0C1hRRRp8nh9nqLjaHRkL4nB0NqbqTValLPhLvg8sifdLcN90rDOBkbRIfPGDMpRg'},
#  {'participantId': 2,
#   'puuid': '4hDu8mxm-kKJCCywhMhTYAL_-Rc7zioy43SCBu-WmX_D7f0_qj5gGUTJbumWWf3uzZBL6lCWFBWUDA'},
#  {'participantId': 3,
#   'puuid': 'esjEC4e-7jBlXx6em_R1Pb6aynwX6PJMOl_bg_dYt90TpdWkWIe4nhK32xfOBLAMyKqoBb8gC0IEmw'},
#  {'participantId': 4,
#   'puuid': 'AiVu4GHGGqsgkg2L6JmIjFDql0DXxqsJwWXFGZjU8rzEMc8VRrD6T3rNPRjtMBY_tucEp-YBimnojg'},
#  {'participantId': 5,
#   'puuid': 'k6XO2jDE_y-3W3hlARpO3w_heaX14GQxjZLkjLESOPeqo9LGQrCAAGoDkoMM7aT1VM1RZU7zSAUynQ'},
#  {'participantId': 6,
#   'puuid': 'Qm9mLqmVZE1UpIPGpL8nY8AQ7WUuxmXT6D6DQdInpJcQdK92G95LKE9YurKHa-WVufpAvY9D1M9ikQ'},
#  {'participantId': 7,
#   'puuid': 'lM8t1_cGIf9uvZKa_UG-YwQhsgqGFAL0rJ8KjAI486ZfAE8DkVePJ-UBIPg657u-FIfWokCfeIvkvg'},
#  {'participantId': 8,
#   'puuid': 'N-v4h4uTCNecSd1Ih46vlEnNUFCj-7_0LhyxkRHKRulB9fkixeMP74QuPe6p7em337wnnEu2LC0Lbg'},
#  {'participantId': 9,
#   'puuid': '6AyEQIqKkBR7093SNlgw8sC6rYt8ihoyPTuVLQDiw9JUmsmYkG6XAtc89kqH65gXel6IpsGwhfZjiA'},
#  {'participantId': 10,
#   'puuid': 'vvLc4NlhyXiDJSZMqTgysFGIbk95Tfz5n-G89Rbh4GYNaGNNmS0asoq0pQrY8ecQm8ND_SrtIJKpQA'}]

# %%
pd.DataFrame(pd.DataFrame(timeline_data)['info'][4])
# Out:
#                                                events  \
# 0   [{'realTimestamp': 1652581976804, 'timestamp':...
# 1   [{'itemId': 1035, 'participantId': 2, 'timesta...
# 2   [{'levelUpType': 'NORMAL', 'participantId': 6,...
# 3   [{'itemId': 2003, 'participantId': 5, 'timesta...
# 4   [{'creatorId': 10, 'timestamp': 180198, 'type'...
# 5   [{'itemId': 2003, 'participantId': 9, 'timesta...
# 6   [{'itemId': 1042, 'participantId': 9, 'timesta...
# 7   [{'level': 6, 'participantId': 8, 'timestamp':...
# 8   [{'killerId': 9, 'timestamp': 421572, 'type': ...
# 9   [{'levelUpType': 'NORMAL', 'participantId': 10...
# 10  [{'itemId': 1028, 'participantId': 3, 'timesta...
# 11  [{'creatorId': 6, 'timestamp': 600412, 'type':...
# 12  [{'creatorId': 8, 'timestamp': 660678, 'type':...
# 13  [{'itemId': 1036, 'participantId': 4, 'timesta...
# 14  [{'level': 10, 'participantId': 1, 'timestamp'...
# 15  [{'killerId': 5, 'timestamp': 840368, 'type': ...
# 16  [{'assistingParticipantIds': [1], 'bounty': 30...
# 17  [{'creatorId': 9, 'timestamp': 962320, 'type':...
# 18  [{'assistingParticipantIds': [2, 3, 4, 5], 'bo...
# 19  [{'afterId': 0, 'beforeId': 3067, 'goldGain': ...
# 20  [{'creatorId': 8, 'timestamp': 1141644, 'type'...
# 21  [{'itemId': 1028, 'participantId': 3, 'timesta...
# 22  [{'itemId': 1036, 'participantId': 4, 'timesta...
# 23  [{'creatorId': 10, 'timestamp': 1320550, 'type...
# 24  [{'killerId': 3, 'timestamp': 1388847, 'type':...
#
#                                     participantFrames  timestamp
# 0   {'1': {'championStats': {'abilityHaste': 0, 'a...          0
# 1   {'1': {'championStats': {'abilityHaste': 0, 'a...      60025
# 2   {'1': {'championStats': {'abilityHaste': 0, 'a...     120029
# 3   {'1': {'championStats': {'abilityHaste': 0, 'a...     180048
# 4   {'1': {'championStats': {'abilityHaste': 0, 'a...     240062
# 5   {'1': {'championStats': {'abilityHaste': 0, 'a...     300107
# 6   {'1': {'championStats': {'abilityHaste': 0, 'a...     360111
# 7   {'1': {'championStats': {'abilityHaste': 0, 'a...     420119
# 8   {'1': {'championStats': {'abilityHaste': 0, 'a...     480137
# 9   {'1': {'championStats': {'abilityHaste': 0, 'a...     540166
# 10  {'1': {'championStats': {'abilityHaste': 0, 'a...     600181
# 11  {'1': {'championStats': {'abilityHaste': 0, 'a...     660183
# 12  {'1': {'championStats': {'abilityHaste': 0, 'a...     720200
# 13  {'1': {'championStats': {'abilityHaste': 0, 'a...     780208
# 14  {'1': {'championStats': {'abilityHaste': 0, 'a...     840236
# 15  {'1': {'championStats': {'abilityHaste': 0, 'a...     900245
# 16  {'1': {'championStats': {'abilityHaste': 0, 'a...     960272
# 17  {'1': {'championStats': {'abilityHaste': 0, 'a...    1020300
# 18  {'1': {'championStats': {'abilityHaste': 0, 'a...    1080328
# 19  {'1': {'championStats': {'abilityHaste': 0, 'a...    1140356
# 20  {'1': {'championStats': {'abilityHaste': 0, 'a...    1200379
# 21  {'1': {'championStats': {'abilityHaste': 0, 'a...    1260388
# 22  {'1': {'championStats': {'abilityHaste': 0, 'a...    1320418
# 23  {'1': {'championStats': {'abilityHaste': 0, 'a...    1380423
# 24  {'1': {'championStats': {'abilityHaste': 0, 'a...    1410137

# %%
timeline_data['info']['frames'][7]
# Out:
# {'events': [{'level': 6,
#    'participantId': 8,
#    'timestamp': 360342,
#    'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 8,
#    'skillSlot': 4,
#    'timestamp': 361732,
#    'type': 'SKILL_LEVEL_UP'},
#   {'level': 6, 'participantId': 6, 'timestamp': 365168, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 6,
#    'skillSlot': 4,
#    'timestamp': 366093,
#    'type': 'SKILL_LEVEL_UP'},
#   {'level': 5, 'participantId': 4, 'timestamp': 369000, 'type': 'LEVEL_UP'},
#   {'level': 5, 'participantId': 9, 'timestamp': 370387, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 9,
#    'skillSlot': 1,
#    'timestamp': 371443,
#    'type': 'SKILL_LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 4,
#    'skillSlot': 1,
#    'timestamp': 373095,
#    'type': 'SKILL_LEVEL_UP'},
#   {'level': 6, 'participantId': 1, 'timestamp': 376628, 'type': 'LEVEL_UP'},
#   {'creatorId': 8,
#    'timestamp': 377388,
#    'type': 'WARD_PLACED',
#    'wardType': 'UNDEFINED'},
#   {'level': 4, 'participantId': 10, 'timestamp': 379600, 'type': 'LEVEL_UP'},
#   {'itemId': 2003,
#    'participantId': 1,
#    'timestamp': 381021,
#    'type': 'ITEM_DESTROYED'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 10,
#    'skillSlot': 2,
#    'timestamp': 381979,
#    'type': 'SKILL_LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 1,
#    'skillSlot': 4,
#    'timestamp': 382342,
#    'type': 'SKILL_LEVEL_UP'},
#   {'itemId': 1028,
#    'participantId': 6,
#    'timestamp': 387464,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 1028,
#    'participantId': 6,
#    'timestamp': 387464,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 6660,
#    'participantId': 6,
#    'timestamp': 387464,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 2003,
#    'participantId': 4,
#    'timestamp': 387729,
#    'type': 'ITEM_DESTROYED'},
#   {'creatorId': 9,
#    'timestamp': 390373,
#    'type': 'WARD_PLACED',
#    'wardType': 'UNDEFINED'},
#   {'level': 5, 'participantId': 2, 'timestamp': 391961, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 2,
#    'skillSlot': 1,
#    'timestamp': 392755,
#    'type': 'SKILL_LEVEL_UP'},
#   {'creatorId': 9,
#    'timestamp': 399164,
#    'type': 'WARD_PLACED',
#    'wardType': 'UNDEFINED'},
#   {'killerId': 6,
#    'timestamp': 400717,
#    'type': 'WARD_KILL',
#    'wardType': 'CONTROL_WARD'},
#   {'creatorId': 8,
#    'timestamp': 401774,
#    'type': 'WARD_PLACED',
#    'wardType': 'UNDEFINED'},
#   {'itemId': 2010,
#    'participantId': 4,
#    'timestamp': 406466,
#    'type': 'ITEM_DESTROYED'},
#   {'level': 5, 'participantId': 7, 'timestamp': 413568, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 7,
#    'skillSlot': 1,
#    'timestamp': 414890,
#    'type': 'SKILL_LEVEL_UP'},
#   {'itemId': 1028,
#    'participantId': 3,
#    'timestamp': 418258,
#    'type': 'ITEM_PURCHASED'},
#   {'creatorId': 9,
#    'timestamp': 418986,
#    'type': 'WARD_PLACED',
#    'wardType': 'UNDEFINED'}],
#  'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 56,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 102,
#     'attackSpeed': 149,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 15,
#     'cooldownReduction': 0,
#     'health': 834,
#     'healthMax': 1046,
#     'healthRegen': 55,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 37,
#     'movementSpeed': 365,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 512,
#     'powerMax': 644,
#     'powerRegen': 22,
#     'spellVamp': 0},
#    'currentGold': 444,
#    'damageStats': {'magicDamageDone': 278,
#     'magicDamageDoneToChampions': 278,
#     'magicDamageTaken': 884,
#     'physicalDamageDone': 12463,
#     'physicalDamageDoneToChampions': 2195,
#     'physicalDamageTaken': 2312,
#     'totalDamageDone': 13256,
#     'totalDamageDoneToChampions': 2653,
#     'totalDamageTaken': 3196,
#     'trueDamageDone': 514,
#     'trueDamageDoneToChampions': 178,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 6,
#    'minionsKilled': 47,
#    'participantId': 1,
#    'position': {'x': 2349, 'y': 11848},
#    'timeEnemySpentControlled': 49324,
#    'totalGold': 2344,
#    'xp': 3058},
#   '2': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 65,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 99,
#     'attackSpeed': 128,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 801,
#     'healthMax': 839,
#     'healthRegen': 37,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 35,
#     'movementSpeed': 365,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 75,
#     'powerMax': 448,
#     'powerRegen': 131,
#     'spellVamp': 0},
#    'currentGold': 1713,
#    'damageStats': {'magicDamageDone': 2539,
#     'magicDamageDoneToChampions': 230,
#     'magicDamageTaken': 965,
#     'physicalDamageDone': 16256,
#     'physicalDamageDoneToChampions': 1381,
#     'physicalDamageTaken': 2308,
#     'totalDamageDone': 20992,
#     'totalDamageDoneToChampions': 1612,
#     'totalDamageTaken': 3471,
#     'trueDamageDone': 2196,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 197},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 32,
#    'level': 5,
#    'minionsKilled': 3,
#    'participantId': 2,
#    'position': {'x': 6909, 'y': 5234},
#    'timeEnemySpentControlled': 118692,
#    'totalGold': 2938,
#    'xp': 2149},
#   '3': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 9,
#     'armor': 43,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 70,
#     'attackSpeed': 104,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 10,
#     'cooldownReduction': 0,
#     'health': 937,
#     'healthMax': 1332,
#     'healthRegen': 31,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 43,
#     'movementSpeed': 365,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 0,
#     'powerMax': 0,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 258,
#    'damageStats': {'magicDamageDone': 6730,
#     'magicDamageDoneToChampions': 735,
#     'magicDamageTaken': 1800,
#     'physicalDamageDone': 3420,
#     'physicalDamageDoneToChampions': 369,
#     'physicalDamageTaken': 2023,
#     'totalDamageDone': 10254,
#     'totalDamageDoneToChampions': 1208,
#     'totalDamageTaken': 4015,
#     'trueDamageDone': 104,
#     'trueDamageDoneToChampions': 104,
#     'trueDamageTaken': 191},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 5,
#    'minionsKilled': 29,
#    'participantId': 3,
#    'position': {'x': 869, 'y': 814},
#    'timeEnemySpentControlled': 43117,
#    'totalGold': 2028,
#    'xp': 2296},
#   '4': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 40,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 93,
#     'attackSpeed': 157,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 556,
#     'healthMax': 801,
#     'healthRegen': 12,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 325,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 567,
#     'powerMax': 1041,
#     'powerRegen': 21,
#     'spellVamp': 0},
#    'currentGold': 914,
#    'damageStats': {'magicDamageDone': 272,
#     'magicDamageDoneToChampions': 272,
#     'magicDamageTaken': 327,
#     'physicalDamageDone': 12153,
#     'physicalDamageDoneToChampions': 1771,
#     'physicalDamageTaken': 1114,
#     'totalDamageDone': 12425,
#     'totalDamageDoneToChampions': 2043,
#     'totalDamageTaken': 1490,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 48},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 5,
#    'minionsKilled': 48,
#    'participantId': 4,
#    'position': {'x': 10844, 'y': 1413},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 2164,
#    'xp': 1953},
#   '5': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 26,
#     'armor': 42,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 58,
#     'attackSpeed': 105,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 431,
#     'healthMax': 759,
#     'healthRegen': 13,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 496,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 384,
#     'powerMax': 637,
#     'powerRegen': 42,
#     'spellVamp': 0},
#    'currentGold': 449,
#    'damageStats': {'magicDamageDone': 3499,
#     'magicDamageDoneToChampions': 1269,
#     'magicDamageTaken': 477,
#     'physicalDamageDone': 2067,
#     'physicalDamageDoneToChampions': 478,
#     'physicalDamageTaken': 1119,
#     'totalDamageDone': 5638,
#     'totalDamageDoneToChampions': 1820,
#     'totalDamageTaken': 1685,
#     'trueDamageDone': 72,
#     'trueDamageDoneToChampions': 72,
#     'trueDamageTaken': 88},
#    'goldPerSecond': 20,
#    'jungleMinionsKilled': 0,
#    'level': 4,
#    'minionsKilled': 1,
#    'participantId': 5,
#    'position': {'x': 10988, 'y': 1235},
#    'timeEnemySpentControlled': 56654,
#    'totalGold': 1899,
#    'xp': 1555},
#   '6': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 55,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 82,
#     'attackSpeed': 117,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 1134,
#     'healthMax': 1463,
#     'healthRegen': 52,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 36,
#     'movementSpeed': 301,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 402,
#     'powerMax': 697,
#     'powerRegen': 20,
#     'spellVamp': 0},
#    'currentGold': 225,
#    'damageStats': {'magicDamageDone': 2469,
#     'magicDamageDoneToChampions': 524,
#     'magicDamageTaken': 268,
#     'physicalDamageDone': 7786,
#     'physicalDamageDoneToChampions': 744,
#     'physicalDamageTaken': 2369,
#     'totalDamageDone': 10256,
#     'totalDamageDoneToChampions': 1269,
#     'totalDamageTaken': 2735,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 98},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 6,
#    'minionsKilled': 34,
#    'participantId': 6,
#    'position': {'x': 2136, 'y': 11658},
#    'timeEnemySpentControlled': 79795,
#    'totalGold': 1835,
#    'xp': 2839},
#   '7': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 54,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 113,
#     'attackSpeed': 108,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 10,
#     'cooldownReduction': 0,
#     'health': 672,
#     'healthMax': 847,
#     'healthRegen': 20,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 35,
#     'movementSpeed': 365,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 466,
#     'powerMax': 564,
#     'powerRegen': 53,
#     'spellVamp': 0},
#    'currentGold': 376,
#    'damageStats': {'magicDamageDone': 2346,
#     'magicDamageDoneToChampions': 73,
#     'magicDamageTaken': 1252,
#     'physicalDamageDone': 19083,
#     'physicalDamageDoneToChampions': 1911,
#     'physicalDamageTaken': 4103,
#     'totalDamageDone': 23624,
#     'totalDamageDoneToChampions': 1993,
#     'totalDamageTaken': 5507,
#     'trueDamageDone': 2194,
#     'trueDamageDoneToChampions': 8,
#     'trueDamageTaken': 152},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 36,
#    'level': 5,
#    'minionsKilled': 1,
#    'participantId': 7,
#    'position': {'x': 10453, 'y': 4961},
#    'timeEnemySpentControlled': 86783,
#    'totalGold': 2051,
#    'xp': 1980},
#   '8': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 57,
#     'armor': 40,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 71,
#     'attackSpeed': 119,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 813,
#     'healthMax': 923,
#     'healthRegen': 17,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 340,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 533,
#     'powerMax': 1048,
#     'powerRegen': 21,
#     'spellVamp': 0},
#    'currentGold': 1201,
#    'damageStats': {'magicDamageDone': 10198,
#     'magicDamageDoneToChampions': 2768,
#     'magicDamageTaken': 517,
#     'physicalDamageDone': 4784,
#     'physicalDamageDoneToChampions': 1455,
#     'physicalDamageTaken': 1248,
#     'totalDamageDone': 15542,
#     'totalDamageDoneToChampions': 4699,
#     'totalDamageTaken': 1870,
#     'trueDamageDone': 559,
#     'trueDamageDoneToChampions': 476,
#     'trueDamageTaken': 104},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 6,
#    'minionsKilled': 48,
#    'participantId': 8,
#    'position': {'x': 8038, 'y': 7606},
#    'timeEnemySpentControlled': 41590,
#    'totalGold': 3011,
#    'xp': 3001},
#   '9': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 40,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 145,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 812,
#     'healthMax': 872,
#     'healthRegen': 10,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 355,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 380,
#     'powerMax': 554,
#     'powerRegen': 16,
#     'spellVamp': 0},
#    'currentGold': 648,
#    'damageStats': {'magicDamageDone': 167,
#     'magicDamageDoneToChampions': 45,
#     'magicDamageTaken': 716,
#     'physicalDamageDone': 14122,
#     'physicalDamageDoneToChampions': 1814,
#     'physicalDamageTaken': 1056,
#     'totalDamageDone': 14290,
#     'totalDamageDoneToChampions': 1860,
#     'totalDamageTaken': 1772,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 5,
#    'minionsKilled': 44,
#    'participantId': 9,
#    'position': {'x': 12022, 'y': 3263},
#    'timeEnemySpentControlled': 11793,
#    'totalGold': 3098,
#    'xp': 2092},
#   '10': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 33,
#     'armor': 44,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 58,
#     'attackSpeed': 105,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 576,
#     'healthMax': 667,
#     'healthRegen': 13,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 380,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 444,
#     'powerMax': 612,
#     'powerRegen': 37,
#     'spellVamp': 0},
#    'currentGold': 250,
#    'damageStats': {'magicDamageDone': 490,
#     'magicDamageDoneToChampions': 387,
#     'magicDamageTaken': 582,
#     'physicalDamageDone': 1351,
#     'physicalDamageDoneToChampions': 463,
#     'physicalDamageTaken': 790,
#     'totalDamageDone': 1882,
#     'totalDamageDoneToChampions': 892,
#     'totalDamageTaken': 1373,
#     'trueDamageDone': 41,
#     'trueDamageDoneToChampions': 41,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 20,
#    'jungleMinionsKilled': 0,
#    'level': 4,
#    'minionsKilled': 0,
#    'participantId': 10,
#    'position': {'x': 12096, 'y': 3501},
#    'timeEnemySpentControlled': 9582,
#    'totalGold': 1700,
#    'xp': 1381}},
#  'timestamp': 420119}

# %% [markdown]
# game = `time = lol_watcher.match.timeline_by_match(region= player_routing, match_id= 'matchId')`  => `pd.DataFrame(pd.DataFrame(time)['info'][4])`

# %% [markdown]
# # Kills from each player during a match

# %%
def getKills(game):
    kills = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'CHAMPION_KILL':
                kills.append(event) 
    kills_df = pd.DataFrame(kills)
    kills_count = kills_df[['killerId', 'victimId']].groupby(by='killerId', axis=0).count()
    return kills_count

# %%
getKills(timeline_data)
# Out:
#           victimId
# killerId
# 1                1
# 2                5
# 3                2
# 4                1
# 5                1
# 6                1
# 7                3
# 8                8
# 9                2
# 10               2

# %% [markdown]
# # VisionScore from each player during a match

# %% [markdown]
# Cannot calculate vision score but will have a supplemental.

# %%
wards = []
def getWardsPlaced(game):
    wards = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'WARD_PLACED':
                wards.append(event) 
    return wards

# %%
wards_df = pd.DataFrame(getWardsPlaced(timeline_data))
wards_df = wards_df[wards_df.wardType != 'UNDEFINED']
wards_count = wards_df[['creatorId', 'type']].groupby(by='creatorId', axis=0).count()
wards_count.index.rename('participantId',inplace=True)
wards_count.rename(columns={'type':'wards_placed'}, inplace=True)
wards_count.reset_index(inplace=True)

# %%
wardsK = []
def getWardsKilled(game):
    wardsK = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'WARD_KILL':
                wardsK.append(event) 
    return wardsK

# %%
wardsK_df = pd.DataFrame(getWardsKilled(timeline_data))
wardsK_df = wardsK_df[wardsK_df.wardType != 'UNDEFINED']
wardsK_count = wardsK_df[['killerId', 'type']].groupby(by='killerId', axis=0).count()
wardsK_count.index.rename('participantId',inplace=True)
wardsK_count.rename(columns={'type':'wards_destroyed'}, inplace=True)
wardsK_count.reset_index(inplace=True)

# %%
tot_wards_df = wards_count.set_index('participantId').join(wardsK_count.set_index('participantId'), how='left').fillna(0)
tot_wards_df.wards_destroyed = tot_wards_df.wards_destroyed.astype(int)
tot_wards_df['calc_vision_score'] = tot_wards_df.wards_placed + tot_wards_df.wards_destroyed
tot_wards_df
# Out:
#                wards_placed  wards_destroyed  calc_vision_score
# participantId
# 1                         4                0                  4
# 2                         5                1                  6
# 3                         5                0                  5
# 4                         5                2                  7
# 5                         5                4                  9
# 6                         3                1                  4
# 7                         2                0                  2
# 8                         5                0                  5
# 9                         3                4                  7
# 10                        8                0                  8

# %% [markdown]
# # get vision score comparison for vision = place + killed vs end of game vision score.  place+killed should equal the total timeline

# %%
def getVisionScore(game):
    wardsK = defaultdict(int)
    wardsP = defaultdict(int)
    wardinfo = [wardsP, wardsK]
    
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if ((event['type'] == 'WARD_KILL') and (event['wardType'] != 'UNDEFINED')) : 
                if event['killerId'] in wardsK: 
                    wardsK[event['killerId']] += 1
                else:
                    wardsK[event['killerId']] =1
            elif ((event['type'] == 'WARD_PLACED') and (event['wardType'] != 'UNDEFINED')) :
                if event['creatorId'] in wardsP: 
                    wardsP[event['creatorId']] += 1
                else:
                    wardsP[event['creatorId']] = 1 
    wardinfo_df = pd.DataFrame(wardinfo).T.sort_index().rename(columns={0:'wards_placed',1:'wards_destroyed'}).fillna(0)
    wardinfo_df['VisionScore'] = wardinfo_df.wards_placed + wardinfo_df.wards_destroyed
    return wardinfo_df[['VisionScore']]

# %%
getVisionScore(timeline_data)
# Out:
#     VisionScore
# 1           4.0
# 2           6.0
# 3           5.0
# 4           7.0
# 5           9.0
# 6           4.0
# 7           2.0
# 8           5.0
# 9           7.0
# 10          8.0

# %%
wardsK = defaultdict(int)
def getWardsKilled(game):
    for frame in game['info']['frames']:
        for event in frame['events']:
            if ((event['type'] == 'WARD_KILL') and (event['wardType'] != 'UNDEFINED')) : 
                if event['killerId'] in wardsK: 
                    wardsK[event['killerId']] += 1
                else:
                    wardsK[event['killerId']] =1
    return pd.DataFrame.from_dict(wardsK, orient='index', columns=['count']).sort_index()

# %%
getWardsKilled_df = getWardsKilled(timeline_data)
getWardsKilled_df
# Out:
#     count
# 1       1
# 2       4
# 3       1
# 4       4
# 5       4
# 6       1
# 7       1
# 8       1
# 9       9
# 10      3

# %%
tot_wards_df = wards_count.set_index('participantId').join(wardsK_count.set_index('participantId'), how='left').fillna(0)
tot_wards_df.wards_destroyed = tot_wards_df.wards_destroyed.astype(int)
tot_wards_df['calc_vision_score'] = tot_wards_df.wards_placed + tot_wards_df.wards_destroyed
tot_wards_df
# Out:
#                wards_placed  wards_destroyed  calc_vision_score
# participantId
# 1                         4                0                  4
# 2                         5                1                  6
# 3                         5                0                  5
# 4                         5                2                  7
# 5                         5                4                  9
# 6                         3                1                  4
# 7                         2                0                  2
# 8                         5                0                  5
# 9                         3                4                  7
# 10                        8                0                  8

# %%
resp = requests.get(f'https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4286751232?api_key={api_keys}')

# %%
game_time_mins = pd.DataFrame(resp.json())['info']['gameDuration'] / 60

# %%
pd.DataFrame(resp.json())['info'][2][0]
# Out:
# {'assists': 19,
#  'baronKills': 0,
#  'bountyLevel': 2,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 300,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 1.5,
#   'baronBuffGoldAdvantageOverThreshold': 2,
#   'baronTakedowns': 2,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 1,
#   'damagePerMinute': 463.9944676416154,
#   'damageTakenOnTeamPercentage': 0.2639997854714267,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 4,
#   'dodgeSkillShotsSmallWindow': 37,
#   'doubleAces': 0,
#   'dragonTakedowns': 3,
#   'earliestBaron': 1718.545547682225,
#   'earliestDragonTakedown': 1177.6868604925226,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 54,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 1,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilledTime': 778.4946581310302,
#   'flawlessAces': 0,
#   'fullTeamTakedown': 0,
#   'gameLength': 2259.64945030298,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 406.38945776329257,
#   'hadAfkTeammate': 0,
#   'hadOpenNexus': 0,
#   'highestCrowdControlScore': 1,
#   'immobilizeAndKillWithAlly': 14,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 0,
#   'kda': 5.75,
#   'killAfterHiddenWithAlly': 2,
#   'killParticipation': 0.8214285714285714,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killsNearEnemyTurret': 0,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 0,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 6,
#   'landSkillShotsEarlyGame': 2,
#   'laneMinionsFirst10Minutes': 82,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxKillDeficit': 6,
#   'moreEnemyJungleThanOpponent': -140.20000010728836,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 1,
#   'multikillsAfterAggressiveFlash': 0,
#   'mythicItemUsed': 7004,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 1,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 15,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'skillshotsDodged': 23,
#   'skillshotsHit': 27,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 0,
#   'soloTurretsLategame': 1,
#   'stealthWardsPlaced': 6,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 6,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 23,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirst25Minutes': 8,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 2,
#   'teamDamagePercentage': 0.11895605382925971,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 1,
#   'teleportTakedowns': 2,
#   'threeWardsOneSweeperCount': 0,
#   'tookLargeDamageSurvived': 2,
#   'turretPlatesTaken': 1,
#   'turretTakedowns': 5,
#   'turretsTakenWithRiftHerald': 0,
#   'twentyMinionsIn3SecondsCount': 0,
#   'unseenRecalls': 0,
#   'visionScorePerMinute': 1.5210290321452273,
#   'wardTakedowns': 5,
#   'wardTakedownsBefore20M': 0,
#   'wardsGuarded': 0},
#  'champExperience': 21630,
#  'champLevel': 18,
#  'championId': 516,
#  'championName': 'Ornn',
#  'championTransform': 0,
#  'consumablesPurchased': 2,
#  'damageDealtToBuildings': 2138,
#  'damageDealtToObjectives': 9730,
#  'damageDealtToTurrets': 2138,
#  'damageSelfMitigated': 67463,
#  'deaths': 4,
#  'detectorWardsPlaced': 1,
#  'doubleKills': 1,
#  'dragonKills': 1,
#  'eligibleForProgression': True,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'goldEarned': 15304,
#  'goldSpent': 14355,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 1,
#  'inhibitorTakedowns': 2,
#  'inhibitorsLost': 0,
#  'item0': 4401,
#  'item1': 7004,
#  'item2': 3111,
#  'item3': 3121,
#  'item4': 3083,
#  'item5': 3082,
#  'item6': 3363,
#  'itemsPurchased': 27,
#  'killingSprees': 2,
#  'kills': 4,
#  'lane': 'TOP',
#  'largestCriticalStrike': 0,
#  'largestKillingSpree': 2,
#  'largestMultiKill': 2,
#  'longestTimeSpentLiving': 607,
#  'magicDamageDealt': 71720,
#  'magicDamageDealtToChampions': 9355,
#  'magicDamageTaken': 14790,
#  'neutralMinionsKilled': 6,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5003, 'flex': 5002, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8360, 'var1': 12, 'var2': 0, 'var3': 0},
#      {'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#      {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#      {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#     'style': 8300},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8444, 'var1': 2724, 'var2': 0, 'var3': 0},
#      {'perk': 8242, 'var1': 94, 'var2': 0, 'var3': 0}],
#     'style': 8400}]},
#  'physicalDamageDealt': 87390,
#  'physicalDamageDealtToChampions': 7834,
#  'physicalDamageTaken': 17487,
#  'profileIcon': 4473,
#  'puuid': 'fc4x1hr0bnyvSo_7gZK3IAVMwd_Hl_g7CaWnEu_3t1Tbc3c7AM_W136nH7hyHnj3wKYVPl_2vvhJyg',
#  'quadraKills': 0,
#  'riotIdName': '',
#  'riotIdTagline': '',
#  'role': 'SOLO',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 120,
#  'spell2Casts': 103,
#  'spell3Casts': 57,
#  'spell4Casts': 20,
#  'summoner1Casts': 7,
#  'summoner1Id': 4,
#  'summoner2Casts': 7,
#  'summoner2Id': 12,
#  'summonerId': 'GxGuQchzj9viBXv8NkFk8Vs5blsr9w1DyaXTwBV4QzQEi38',
#  'summonerLevel': 535,
#  'summonerName': 'MySwordCrimson',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 37,
#  'timePlayed': 2259,
#  'totalDamageDealt': 163135,
#  'totalDamageDealtToChampions': 17474,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 36639,
#  'totalHeal': 3075,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 230,
#  'totalTimeCCDealt': 538,
#  'totalTimeSpentDead': 143,
#  'totalUnitsHealed': 1,
#  'tripleKills': 0,
#  'trueDamageDealt': 4024,
#  'trueDamageDealtToChampions': 284,
#  'trueDamageTaken': 4360,
#  'turretKills': 1,
#  'turretTakedowns': 5,
#  'turretsLost': 2,
#  'unrealKills': 0,
#  'visionScore': 57,
#  'visionWardsBoughtInGame': 1,
#  'wardsKilled': 5,
#  'wardsPlaced': 11,
#  'win': True}

# %%
wards = []
def getWardsPlaced(game):
    wards = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'WARD_PLACED':
                wards.append(event) 
    return wards

# %%
visionpermin = []
for vision in pd.DataFrame(resp.json())['info'][2]:
    visionpermin.append(vision['challenges']['visionScorePerMinute'])

vision15calc = []    
for time in visionpermin:
    vision15calc.append(time*15)
       
    
visionTot = []    
for time in visionpermin:
    visionTot.append(time*game_time_mins)

# %%
visionScore = []
for vision in pd.DataFrame(resp.json())['info'][2]:
    visionScore.append(vision['visionScore'])

# %%
tot_wards_df['vision15calc'] = vision15calc
tot_wards_df['visionTot'] = visionTot
tot_wards_df['visionScore'] = visionScore
tot_wards_df
# Out:
#                wards_placed  wards_destroyed  calc_vision_score  vision15calc  \
# participantId
# 1                         4                0                  4     22.815435
# 2                         5                1                  6     21.390740
# 3                         5                0                  5      9.867581
# 4                         5                2                  7     15.026210
# 5                         5                4                  9     51.663249
# 6                         3                1                  4     19.659966
# 7                         2                0                  2     10.259999
# 8                         5                0                  5     17.146193
# 9                         3                4                  7     10.098806
# 10                        8                0                  8     41.543809
#
#                 visionTot  visionScore
# participantId
# 1               57.266743           57
# 2               53.690756           53
# 3               24.767627           24
# 4               37.715788           37
# 5              129.674755          129
# 6               49.346516           49
# 7               25.752596           25
# 8               43.036944           43
# 9               25.348004           25
# 10             104.274961          104

# %%
tot_wards_df.corr()
# Out:
#                    wards_placed  wards_destroyed  calc_vision_score  \
# wards_placed           1.000000        -0.166349           0.654031
# wards_destroyed       -0.166349         1.000000           0.637130
# calc_vision_score      0.654031         0.637130           1.000000
# vision15calc           0.582735         0.268263           0.661293
# visionTot              0.582735         0.268263           0.661293
# visionScore            0.583594         0.266700           0.660765
#
#                    vision15calc  visionTot  visionScore
# wards_placed           0.582735   0.582735     0.583594
# wards_destroyed        0.268263   0.268263     0.266700
# calc_vision_score      0.661293   0.661293     0.660765
# vision15calc           1.000000   1.000000     0.999973
# visionTot              1.000000   1.000000     0.999973
# visionScore            0.999973   0.999973     1.000000

# %% [markdown]
# # getAssists Function

# %%
def getAssists(game):
    assists = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'CHAMPION_KILL':
                assists.append(event) 
    assists_df = pd.DataFrame(assists).dropna()          
    assists_player_df = defaultdict(int)
    for assist in assists_df:
        for death in assist:
            if death in assists_player_df:
                assists_player_df[death] += 1
            else:
                assists_player_df[death] = 1                                  
    return assists_player_df

# %%
getAssists(timeline_data)
# Out:
# defaultdict(int,
#             {'a': 10,
#              's': 7,
#              'i': 16,
#              't': 16,
#              'n': 7,
#              'g': 4,
#              'P': 1,
#              'r': 3,
#              'c': 5,
#              'p': 4,
#              'I': 3,
#              'd': 5,
#              'b': 1,
#              'o': 5,
#              'u': 3,
#              'y': 3,
#              'k': 3,
#              'l': 5,
#              'S': 1,
#              'e': 11,
#              'L': 1,
#              'h': 2,
#              'w': 1,
#              'B': 1,
#              'm': 7,
#              'v': 4,
#              'D': 3,
#              'R': 1})

# %%
# def getAssists(game):
#     assists = []
#     for frame in game['info']['frames'][0:16]:
#         for event in frame['events']:
#             if event['type'] == 'CHAMPION_KILL':
#                 assists.append(event) 
#     return pd.DataFrame(assists).dropna()

# %%
# getAssists(time).head()

# %%
# assists_df = getAssists(time).assistingParticipantIds
# assists_df

# %%
# assists_player_df = defaultdict(int)
# for assist in assists_df:
#     for death in assist:
#         if death in assists_player_df:
#             assists_player_df[death] += 1
#         else:
#             assists_player_df[death] = 1
# assists_player_df

# %%
diff_types = []
for minute in pd.DataFrame(pd.DataFrame(time)['info'][4])['events']:
    for types in minute:
        diff_types.append(types['type'])
set(diff_types)
# Out:
# {'BUILDING_KILL',
#  'CHAMPION_KILL',
#  'CHAMPION_SPECIAL_KILL',
#  'DRAGON_SOUL_GIVEN',
#  'ELITE_MONSTER_KILL',
#  'GAME_END',
#  'ITEM_DESTROYED',
#  'ITEM_PURCHASED',
#  'ITEM_SOLD',
#  'ITEM_UNDO',
#  'LEVEL_UP',
#  'OBJECTIVE_BOUNTY_PRESTART',
#  'PAUSE_END',
#  'SKILL_LEVEL_UP',
#  'TURRET_PLATE_DESTROYED',
#  'WARD_KILL',
#  'WARD_PLACED'}

# %%
kills_df = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(time)['info'][4])['events'][7]) #At the moment not planning to use any information from the 'events'.  In the future may look into platings recieved.  This may be the area but ill need to iterate through everytime stamp before 14 and add them

# %%
kills_df.head()\
# Out:
#    itemId  participantId  timestamp            type  level levelUpType  \
# 0  2003.0            3.0     360298  ITEM_PURCHASED    NaN         NaN
# 1     NaN            7.0     361949        LEVEL_UP    6.0         NaN
# 2     NaN            7.0     362775  SKILL_LEVEL_UP    NaN      NORMAL
# 3     NaN            4.0     362775        LEVEL_UP    5.0         NaN
# 4     NaN            4.0     363403  SKILL_LEVEL_UP    NaN      NORMAL
#
#    skillSlot  creatorId wardType assistingParticipantIds  bounty  \
# 0        NaN        NaN      NaN                     NaN     NaN
# 1        NaN        NaN      NaN                     NaN     NaN
# 2        4.0        NaN      NaN                     NaN     NaN
# 3        NaN        NaN      NaN                     NaN     NaN
# 4        1.0        NaN      NaN                     NaN     NaN
#
#    killStreakLength  killerId position  shutdownBounty victimDamageDealt  \
# 0               NaN       NaN      NaN             NaN               NaN
# 1               NaN       NaN      NaN             NaN               NaN
# 2               NaN       NaN      NaN             NaN               NaN
# 3               NaN       NaN      NaN             NaN               NaN
# 4               NaN       NaN      NaN             NaN               NaN
#
#   victimDamageReceived  victimId laneType  teamId
# 0                  NaN       NaN      NaN     NaN
# 1                  NaN       NaN      NaN     NaN
# 2                  NaN       NaN      NaN     NaN
# 3                  NaN       NaN      NaN     NaN
# 4                  NaN       NaN      NaN     NaN

# %%
kills_df.type.value_counts()
# Out:
# WARD_PLACED               9
# ITEM_PURCHASED            8
# ITEM_DESTROYED            7
# LEVEL_UP                  6
# SKILL_LEVEL_UP            6
# CHAMPION_KILL             4
# TURRET_PLATE_DESTROYED    1
# WARD_KILL                 1
# Name: type, dtype: int64

# %%
kills_df[kills_df['type']=='CHAMPION_KILL']
# Out:
#     itemId  participantId  timestamp           type  level levelUpType  \
# 8      NaN            NaN     374304  CHAMPION_KILL    NaN         NaN
# 10     NaN            NaN     374337  CHAMPION_KILL    NaN         NaN
# 13     NaN            NaN     377046  CHAMPION_KILL    NaN         NaN
# 15     NaN            NaN     381934  CHAMPION_KILL    NaN         NaN
#
#     skillSlot  creatorId wardType assistingParticipantIds  bounty  \
# 8         NaN        NaN      NaN                    [10]   300.0
# 10        NaN        NaN      NaN                     [2]   300.0
# 13        NaN        NaN      NaN                  [2, 5]   219.0
# 15        NaN        NaN      NaN                     NaN   300.0
#
#     killStreakLength  killerId                 position  shutdownBounty  \
# 8                0.0       9.0  {'x': 12573, 'y': 5520}             0.0
# 10               0.0       5.0  {'x': 12710, 'y': 5384}             0.0
# 13               3.0       4.0  {'x': 13593, 'y': 5094}             0.0
# 15               0.0       7.0  {'x': 13526, 'y': 4541}           300.0
#
#                                     victimDamageDealt  \
# 8   [{'basic': False, 'magicDamage': 172, 'name': ...
# 10  [{'basic': False, 'magicDamage': 0, 'name': 'E...
# 13                                                NaN
# 15                                                NaN
#
#                                  victimDamageReceived  victimId laneType  \
# 8   [{'basic': False, 'magicDamage': 0, 'name': 'P...       2.0      NaN
# 10  [{'basic': True, 'magicDamage': 0, 'name': 'Na...       9.0      NaN
# 13  [{'basic': False, 'magicDamage': 167, 'name': ...      10.0      NaN
# 15  [{'basic': True, 'magicDamage': 0, 'name': 'SR...       4.0      NaN
#
#     teamId
# 8      NaN
# 10     NaN
# 13     NaN
# 15     NaN

# %%
def getcs(game):
    participants_15 = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(game)['info'][4])['participantFrames'][15])
    participants_15_df = participants_15.T[['participantId','jungleMinionsKilled','minionsKilled','level']]
    participants_15_df['cs'] = participants_15_df['jungleMinionsKilled'] + participants_15_df['minionsKilled']
    return participants_15_df['cs']

# %%
# time
# Out:
# 2.7695872717611323

# %%
def getlevel(game):
    participants_15 = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(game)['info'][4])['participantFrames'][15])
    participants_15_df = participants_15.T[['participantId','jungleMinionsKilled','minionsKilled','level']]
    return participants_15_df['level']

# %%
participants_15 = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(time)['info'][4])['participantFrames'][15])

# %%
participants_15_df = participants_15.T[['participantId','jungleMinionsKilled','minionsKilled','level']]
participants_15_df['cs'] = participants_15_df['jungleMinionsKilled'] + participants_15_df['minionsKilled']
participants_15_df
# Out:
#    participantId jungleMinionsKilled minionsKilled level   cs
# 1              1                   0           118    10  118
# 2              2                  67            25     9   92
# 3              3                   1           121    11  122
# 4              4                   0           116     8  116
# 5              5                   0            28     8   28
# 6              6                 103            17    11  120
# 7              7                   0           107    10  107
# 8              8                   4            91    10   95
# 9              9                   4           109     9  113
# 10            10                   0            22     7   22

# %%
def getELITE_MONSTER_KILL(game):
    ELITE_MONSTER_KILL = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'ELITE_MONSTER_KILL':
                ELITE_MONSTER_KILL.append(event) 
    ELITE_MONSTER_KILL = pd.DataFrame(ELITE_MONSTER_KILL)            
    return ELITE_MONSTER_KILL[['killerTeamId','monsterType', 'monsterSubType']]

# %%
getELITE_MONSTER_KILL(timeline_data)
# Out:
#    killerTeamId monsterType  monsterSubType
# 0           200      DRAGON  HEXTECH_DRAGON
# 1           100  RIFTHERALD             NaN
# 2           200      DRAGON    WATER_DRAGON

# %%
def getELITE_MONSTER_KILL(game):
    ELITE_MONSTER_KILL = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'ELITE_MONSTER_KILL':
                ELITE_MONSTER_KILL.append(event) 
    ELITE_MONSTER_KILL = pd.DataFrame(ELITE_MONSTER_KILL)                
    if len(ELITE_MONSTER_KILL.columns) == 9:
        return ELITE_MONSTER_KILL[['killerTeamId','monsterType', 'monsterSubType']]
    elif len(ELITE_MONSTER_KILL.columns) == 7:
        return ELITE_MONSTER_KILL[['killerTeamId','monsterType']]
    elif len(ELITE_MONSTER_KILL.columns) == 0:
        return NONE

# %%
getELITE_MONSTER_KILL(timeline)
# Out:
#    killerTeamId monsterType  monsterSubType
# 0           200      DRAGON  HEXTECH_DRAGON
# 1           100  RIFTHERALD             NaN
# 2           200      DRAGON    WATER_DRAGON

# %%
matchdata = lol_watcher.match.by_id(region= player_routing, match_id= 'NA1_4286751232')

# %%
pd.DataFrame(matchdata)['info'][15]
# Out:
# [{'bans': [{'championId': 221, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 498, 'pickTurn': 3},
#    {'championId': 154, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}],
#   'objectives': {'baron': {'first': False, 'kills': 2},
#    'champion': {'first': True, 'kills': 44},
#    'dragon': {'first': False, 'kills': 4},
#    'inhibitor': {'first': True, 'kills': 4},
#    'riftHerald': {'first': True, 'kills': 1},
#    'tower': {'first': True, 'kills': 10}},
#   'teamId': 100,
#   'win': True},
#  {'bans': [{'championId': 107, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 104, 'pickTurn': 8},
#    {'championId': 114, 'pickTurn': 9},
#    {'championId': 203, 'pickTurn': 10}],
#   'objectives': {'baron': {'first': True, 'kills': 1},
#    'champion': {'first': False, 'kills': 28},
#    'dragon': {'first': True, 'kills': 2},
#    'inhibitor': {'first': False, 'kills': 0},
#    'riftHerald': {'first': False, 'kills': 1},
#    'tower': {'first': False, 'kills': 2}},
#   'teamId': 200,
#   'win': False}]

# %%
def getwin(game):

# %%
def getELITE_MONSTER_KILL(game):
    ELITE_MONSTER_KILL = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'ELITE_MONSTER_KILL':
                ELITE_MONSTER_KILL.append(event) 
    return pd.DataFrame(ELITE_MONSTER_KILL).column

# %%
gameInformationList = []

for game in unique_matchIDs:
    timeline = lol_watcher.match.timeline_by_match(region= player_routing, match_id= game)

# %%
gameInformationList = []

for game in unique_matchIDs[0:10]:
    timeline = lol_watcher.match.timeline_by_match(region= player_routing, match_id= game)  
    
    gameInformation = {}
    gameInformation['kills'] = getKills(timeline)
    gameInformation['visionScore'] = getVisionScore(timeline)
    gameInformation['assists'] = getAssists(timeline)
    gameInformation['cs'] = getcs(timeline)
    gameInformation['level'] = getlevel(timeline)
    gameInformation['Epic_Monsters'] = getELITE_MONSTER_KILL(timeline)
    
    gameInformationList.append(gameInformation)
pd.DataFrame(gameInformationList)
# Out:
#                                                kills  \
# 0            victimId
# killerId
# 2       ...
# 1            victimId
# killerId
# 2       ...
# 2            victimId
# killerId
# 1       ...
# 3            victimId
# killerId
# 0       ...
# 4            victimId
# killerId
# 1       ...
# 5            victimId
# killerId
# 1       ...
# 6            victimId
# killerId
# 2       ...
# 7            victimId
# killerId
# 1       ...
# 8            victimId
# killerId
# 2       ...
# 9            victimId
# killerId
# 2       ...
#
#                                          visionScore  \
# 0      VisionScore
# 1           NaN
# 2           5....
# 1      VisionScore
# 1           6.0
# 2           4....
# 2      VisionScore
# 1           NaN
# 2           3....
# 3      VisionScore
# 1           NaN
# 2           3....
# 4      VisionScore
# 1           NaN
# 3           Na...
# 5      VisionScore
# 1           NaN
# 2           9....
# 6      VisionScore
# 1           NaN
# 2           Na...
# 7      VisionScore
# 1           NaN
# 2           5....
# 8      VisionScore
# 1           NaN
# 2           5....
# 9      VisionScore
# 1           7.0
# 2           Na...
#
#                                              assists  \
# 0  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 1  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 2  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 3  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 4  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 5  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 6  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 7  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 8  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
# 9  {2: 2, 4: 2, 7: 3, 6: 2, 10: 3, 5: 3, 8: 2, 9:...
#
#                                                   cs  \
# 0  1     118
# 2      92
# 3     122
# 4     116
# 5     ...
# 1  1     112
# 2      86
# 3      96
# 4      80
# 5     ...
# 2  1     114
# 2      92
# 3     110
# 4      13
# 5     ...
# 3  1      88
# 2      90
# 3     116
# 4     110
# 5     ...
# 4  1     101
# 2     109
# 3     131
# 4      97
# 5     ...
# 5  1     106
# 2     121
# 3      64
# 4     104
# 5     ...
# 6  1     127
# 2      78
# 3      68
# 4      92
# 5     ...
# 7  1      95
# 2      83
# 3      93
# 4     117
# 5     ...
# 8  1     101
# 2     103
# 3      25
# 4      95
# 5     ...
# 9  1     111
# 2      79
# 3     130
# 4     133
# 5     ...
#
#                                                level  \
# 0  1     10
# 2      9
# 3     11
# 4      8
# 5      8
# 6...
# 1  1     10
# 2      9
# 3      9
# 4      8
# 5      8
# 6...
# 2  1     11
# 2     10
# 3     10
# 4      7
# 5     10
# 6...
# 3  1     10
# 2      9
# 3     10
# 4     10
# 5      7
# 6...
# 4  1     11
# 2     11
# 3     11
# 4      8
# 5      8
# 6...
# 5  1     10
# 2     10
# 3     10
# 4     10
# 5      7
# 6...
# 6  1     10
# 2     10
# 3     10
# 4      9
# 5      7
# 6...
# 7  1      9
# 2      9
# 3     10
# 4      9
# 5      7
# 6...
# 8  1     10
# 2     10
# 3      6
# 4      9
# 5      8
# 6...
# 9  1      8
# 2      9
# 3     10
# 4     11
# 5      8
# 6...
#
#                                        Epic_Monsters
# 0     killerTeamId monsterType  monsterSubType
# 0 ...
# 1     killerTeamId monsterType
# 0           200  R...
# 2                                               None
# 3                                               None
# 4     killerTeamId monsterType monsterSubType
# 0  ...
# 5     killerTeamId monsterType  monsterSubType
# 0 ...
# 6     killerTeamId monsterType  monsterSubType
# 0 ...
# 7     killerTeamId monsterType monsterSubType
# 0  ...
# 8                                               None
# 9     killerTeamId monsterType  monsterSubType
# 0 ...

# %%
gameInformationList = []

for game in gamesDataRaw
    participantId = getParticipantIdFromAccountId(game, accountID)
    teamId, ChampionId, win = getTreamAndChamption(game, participantID)
    compositions = getTeamComposition(game)
    
    gameInformation = {}
    gameInformation['win'] = win
    gameInformation ['visionScore'] = participantD[visionScore]
    gameInformation['champion'] = championIdToName[championID]
    gameInformation['patch'] = getPatch(game)
    gameInformation['date'] = getDate(game)
    gameInformation['teamComposition'] = "/".join([championIdToName[chld] for chld in compositions[teamId]])
    gameInformation['enemyTeamComposition'] = "/".join([championIdToName[chld] for chld in compositions[100 if teamId==200 else 200]])
    
    gameInformationList.append(gameInformation)

gameInformationList

# %%
# match_data_big = []
# for match in unique_matchIDs:
#     match_data_big.append(lol_watcher.match.timeline_by_match(region= player_routing, match_id= match))

# %%
# match_data_time = [lol_watcher.match.timeline_by_match(region= player_routing, match_id= match) for match in unique_matchIDs]
