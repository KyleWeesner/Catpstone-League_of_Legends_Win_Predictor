# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import string

import requests
from riotwatcher import LolWatcher, ApiError
import json

# %%
# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = list((get_keys('/Users/weesn/Documents/Flatiron/secrets.json')).values())[0]

# %%
lol_watcher = LolWatcher(f'{api_keys}')
my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'KyleWeez')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise
# Out:
# {'id': 'sxAViHUpUFO1U0yayOWQHuWFBfvQ4iYtUa3dMcxag3UK3eQ', 'accountId': 'TkRmi54Sa-lOuySeCliJQ8BTBRtvAY5gBHkkGJeL9gSs3MQ', 'puuid': 'f9jL5C1IrczsbmdVUxcv8ZcrkWqlpy_6YRP3VgvVNhUIM64Ml-Bd1PFcNM0_nACpWkumdLuj6Ax-gA', 'name': 'KyleWeez', 'profileIconId': 1388, 'revisionDate': 1652937704000, 'summonerLevel': 374}
# [{'leagueId': '371f2307-b230-4972-be37-9647e7a277cf', 'queueType': 'RANKED_FLEX_SR', 'tier': 'GOLD', 'rank': 'IV', 'summonerId': 'sxAViHUpUFO1U0yayOWQHuWFBfvQ4iYtUa3dMcxag3UK3eQ', 'summonerName': 'KyleWeez', 'leaguePoints': 13, 'wins': 27, 'losses': 18, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}, {'leagueId': '0d0cb7a5-3699-4ffb-b246-2a37ceba3e52', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'PLATINUM', 'rank': 'III', 'summonerId': 'sxAViHUpUFO1U0yayOWQHuWFBfvQ4iYtUa3dMcxag3UK3eQ', 'summonerName': 'KyleWeez', 'leaguePoints': 16, 'wins': 44, 'losses': 31, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}]
# {'type': 'champion', 'format': 'standAloneComplex', 'version': '12.9.1', 'data': {'Aatrox': {'version': '12.9.1', 'id': 'Aatrox', 'key': '266', 'name': 'Aatrox', 'title': 'the Darkin Blade', 'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...', 'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}, 'image': {'full': 'Aatrox.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 0, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Fighter', 'Tank'], 'partype': 'Blood Well', 'stats': {'hp': 580, 'hpperlevel': 90, 'mp': 0, 'mpperlevel': 0, 'movespeed': 345, 'armor': 38, 'armorperlevel': 3.25, 'spellblock': 32, 'spellblockperlevel': 1.25, 'attackrange': 175, 'hpregen': 3, 'hpregenperlevel': 1, 'mpregen': 0, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 60, 'attackdamageperlevel': 5, 'attackspeedperlevel': 2.5, 'attackspeed': 0.651}}, 'Ahri': {'version': '12.9.1', 'id': 'Ahri', 'key': '103', 'name': 'Ahri', 'title': 'the Nine-Tailed Fox', 'blurb': 'Innately connected to the latent power of Runeterra, Ahri is a vastaya who can reshape magic into orbs of raw energy. She revels in toying with her prey by manipulating their emotions before devouring their life essence. Despite her predatory nature...', 'info': {'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 5}, 'image': {'full': 'Ahri.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 48, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Mage', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 500, 'hpperlevel': 82, 'mp': 418, 'mpperlevel': 25, 'movespeed': 330, 'armor': 18, 'armorperlevel': 3.5, 'spellblock': 30, 'spellblockperlevel': 0.5, 'attackrange': 550, 'hpregen': 2.5, 'hpregenperlevel': 0.6, 'mpregen': 8, 'mpregenperlevel': 0.8, 'crit': 0, 'critperlevel': 0, 'attackdamage': 53, 'attackdamageperlevel': 3, 'attackspeedperlevel': 2, 'attackspeed': 0.668}}, 'Akali': {'version': '12.9.1', 'id': 'Akali', 'key': '84', 'name': 'Akali', 'title': 'the Rogue Assassin', 'blurb': 'Abandoning the Kinkou Order and her title of the Fist of Shadow, Akali now strikes alone, ready to be the deadly weapon her people need. Though she holds onto all she learned from her master Shen, she has pledged to defend Ionia from its enemies, one...', 'info': {'attack': 5, 'defense': 3, 'magic': 8, 'difficulty': 7}, 'image': {'full': 'Akali.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 96, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Assassin'], 'partype': 'Energy', 'stats': {'hp': 500, 'hpperlevel': 105, 'mp': 200, 'mpperlevel': 0, 'movespeed': 345, 'armor': 23, 'armorperlevel': 3.5, 'spellblock': 37, 'spellblockperlevel': 1.25, 'attackrange': 125, 'hpregen': 9, 'hpregenperlevel': 0.9, 'mpregen': 50, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 62, 'attackdamageperlevel': 3.3, 'attackspeedperlevel': 3.2, 'attackspeed': 0.625}}, 'Akshan': {'version': '12.9.1', 'id': 'Akshan', 'key': '166', 'name': 'Akshan', 'title': 'the Rogue Sentinel', 'blurb': 'Raising an eyebrow in the face of danger, Akshan fights evil with dashing charisma, righteous vengeance, and a conspicuous lack of shirts. He is highly skilled in the art of stealth combat, able to evade the eyes of his enemies and reappear when they...', 'info': {'attack': 0, 'defense': 0, 'magic': 0, 'difficulty': 0}, 'image': {'full': 'Akshan.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 144, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Marksman', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 560, 'hpperlevel': 90, 'mp': 350, 'mpperlevel': 40, 'movespeed': 330, 'armor': 26, 'armorperlevel': 3, 'spellblock': 30, 'spellblockperlevel': 0.5, 'attackrange': 500, 'hpregen': 3.75, 'hpregenperlevel': 0.65, 'mpregen': 8.175, 'mpregenperlevel': 0.7, 'crit': 0, 'critperlevel': 0, 'attackdamage': 52, 'attackd ...
# Summoner with that ridiculous name not found.

# %% [markdown]
# # Test run.  Getting wanted DataFrame using 10  players from challenger

# %%
player_region= 'NA1'.lower()
queue_type= 'RANKED_SOLO_5x5' 
challenger_ladder= lol_watcher.league.challenger_by_queue(region= player_region, 
                                                          queue=queue_type)
challenger = pd.DataFrame(challenger_ladder)

# %%
challenger_players= pd.DataFrame.from_dict(challenger_ladder['entries'])
challenger_info_df = pd.merge(challenger,challenger_players, left_index=True, right_index=True)
challenger_info_df['total_games'] = challenger_info_df['wins'] + challenger_info_df['losses']
challenger_info_df
# Out:
#            tier                              leagueId            queue  \
# 0    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 1    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 2    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 3    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 4    CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# ..          ...                                   ...              ...
# 295  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 296  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 297  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 298  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 299  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
#
#                  name                                            entries  \
# 0    Swain's Villains  {'summonerId': 'GZRlnuOPfHXdr1gZUEJymdgrr0dswk...
# 1    Swain's Villains  {'summonerId': 'y5eVXeHoEHu_cHJkAmj9iG9H03nbAg...
# 2    Swain's Villains  {'summonerId': '25ecBqXZM355EL5Ggldr_067srj-MT...
# 3    Swain's Villains  {'summonerId': 'RMlyfdZ_P0zYHcTSzalcJJb4Y8qz_n...
# 4    Swain's Villains  {'summonerId': '4g0riRM-Uf5Z-jla5LQuITQjnbjhIJ...
# ..                ...                                                ...
# 295  Swain's Villains  {'summonerId': 'rHnVA3trM2NSyUm7pHfCfVd4X41kD6...
# 296  Swain's Villains  {'summonerId': '3ip81TxpAN0KMI9T8XXXTk1nt0yjWI...
# 297  Swain's Villains  {'summonerId': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjU...
# 298  Swain's Villains  {'summonerId': 'dgMcpMRc2quDh4657UI-86sWRPKeHw...
# 299  Swain's Villains  {'summonerId': '6uYiNxO9lta5ao2p2sxKMbDu3KWn7_...
#
#                                             summonerId     summonerName  \
# 0    GZRlnuOPfHXdr1gZUEJymdgrr0dswkW_vb01YrC8uEKG68...           Chime2
# 1     y5eVXeHoEHu_cHJkAmj9iG9H03nbAgRdDG2YAaRu9W8Lg8RG   twtv CitricLoL
# 2      25ecBqXZM355EL5Ggldr_067srj-MTb_6ahLB-18G58Jvm8       Alex Blais
# 3    RMlyfdZ_P0zYHcTSzalcJJb4Y8qz_nts27N3-QvHHrLsur...  crazy thursday4
# 4      4g0riRM-Uf5Z-jla5LQuITQjnbjhIJvgDqS1goaPczjc_wc            Matty
# ..                                                 ...              ...
# 295    rHnVA3trM2NSyUm7pHfCfVd4X41kD6nfTGSFfMMl2YlmEMk         Messages
# 296   3ip81TxpAN0KMI9T8XXXTk1nt0yjWIgM3zcYdqYJ6Sw9P3zz       yukino cat
# 297   yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb           Airren
# 298   dgMcpMRc2quDh4657UI-86sWRPKeHwipqzYisryWsCab8E6c        ScrubNoob
# 299  6uYiNxO9lta5ao2p2sxKMbDu3KWn7_BjjfJ8QaPcz_Cw7R...        Revengeee
#
#      leaguePoints rank  wins  losses  veteran  inactive  freshBlood  \
# 0            1146    I   242     200     True     False       False
# 1             834    I   322     256     True     False       False
# 2             853    I   252     227    False     False       False
# 3            1073    I   296     260     True     False       False
# 4             873    I   185     158    False     False       False
# ..            ...  ...   ...     ...      ...       ...         ...
# 295           793    I   152     129    False     False        True
# 296           849    I   325     304    False     False       False
# 297           837    I   203     179    False     False       False
# 298          1055    I   212     175     True     False       False
# 299          1181    I   208     164     True     False       False
#
#      hotStreak  total_games
# 0         True          442
# 1        False          578
# 2         True          479
# 3        False          556
# 4        False          343
# ..         ...          ...
# 295      False          281
# 296      False          629
# 297       True          382
# 298      False          387
# 299      False          372
#
# [300 rows x 16 columns]

# %%
players10_challenger = challenger_info_df.tail(10)
players10_challenger
# Out:
#            tier                              leagueId            queue  \
# 290  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 291  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 292  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 293  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 294  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 295  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 296  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 297  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 298  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 299  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
#
#                  name                                            entries  \
# 290  Swain's Villains  {'summonerId': 'rNT9BtqsZKf9t3CqkWw-DRL2bCALut...
# 291  Swain's Villains  {'summonerId': 'DkN9tDInFSY1kWalSs3UpdeKAjdvZd...
# 292  Swain's Villains  {'summonerId': 'Dg0TH4NpanJvZDAk99XXBHivrIM5WM...
# 293  Swain's Villains  {'summonerId': 'QKxGB4Y3LRhRLqU8HbHEYnAlhqgMJS...
# 294  Swain's Villains  {'summonerId': '5utPRLI5c0PowiRs6dhwLfgIdUDf2s...
# 295  Swain's Villains  {'summonerId': 'rHnVA3trM2NSyUm7pHfCfVd4X41kD6...
# 296  Swain's Villains  {'summonerId': '3ip81TxpAN0KMI9T8XXXTk1nt0yjWI...
# 297  Swain's Villains  {'summonerId': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjU...
# 298  Swain's Villains  {'summonerId': 'dgMcpMRc2quDh4657UI-86sWRPKeHw...
# 299  Swain's Villains  {'summonerId': '6uYiNxO9lta5ao2p2sxKMbDu3KWn7_...
#
#                                             summonerId   summonerName  \
# 290    rNT9BtqsZKf9t3CqkWw-DRL2bCALutDlZHXjEpW_5Id9Mw0  tommytomato52
# 291  DkN9tDInFSY1kWalSs3UpdeKAjdvZdyF-8q18fXUPxGr2k...        jjking9
# 292    Dg0TH4NpanJvZDAk99XXBHivrIM5WM5YdjmCpn5qST22CUg      FrosFores
# 293   QKxGB4Y3LRhRLqU8HbHEYnAlhqgMJSyEmWMTFtfRClParWYP        RBOMLDR
# 294    5utPRLI5c0PowiRs6dhwLfgIdUDf2sK4gu3Ias82RSdffmI           Topo
# 295    rHnVA3trM2NSyUm7pHfCfVd4X41kD6nfTGSFfMMl2YlmEMk       Messages
# 296   3ip81TxpAN0KMI9T8XXXTk1nt0yjWIgM3zcYdqYJ6Sw9P3zz     yukino cat
# 297   yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb         Airren
# 298   dgMcpMRc2quDh4657UI-86sWRPKeHwipqzYisryWsCab8E6c      ScrubNoob
# 299  6uYiNxO9lta5ao2p2sxKMbDu3KWn7_BjjfJ8QaPcz_Cw7R...      Revengeee
#
#      leaguePoints rank  wins  losses  veteran  inactive  freshBlood  \
# 290           945    I   140     100    False     False       False
# 291           802    I   288     276     True     False       False
# 292           828    I   116      79    False     False        True
# 293          1020    I   132      94     True     False       False
# 294          1160    I   184     147     True     False       False
# 295           793    I   152     129    False     False        True
# 296           849    I   325     304    False     False       False
# 297           837    I   203     179    False     False       False
# 298          1055    I   212     175     True     False       False
# 299          1181    I   208     164     True     False       False
#
#      hotStreak  total_games
# 290      False          240
# 291      False          564
# 292      False          195
# 293      False          226
# 294      False          331
# 295      False          281
# 296      False          629
# 297       True          382
# 298      False          387
# 299      False          372

# %%
players10_challenger.summonerName
# Out:
# 290    tommytomato52
# 291          jjking9
# 292        FrosFores
# 293          RBOMLDR
# 294             Topo
# 295         Messages
# 296       yukino cat
# 297           Airren
# 298        ScrubNoob
# 299        Revengeee
# Name: summonerName, dtype: object

# %%
player_name= players10_challenger.summonerName
player_region= 'NA1'.lower()
player_routing= 'americas'
player_info = []

for player in player_name:
    player_info.append(lol_watcher.summoner.by_name(player_region, player))
player_info
# Out:
# [{'id': 'rNT9BtqsZKf9t3CqkWw-DRL2bCALutDlZHXjEpW_5Id9Mw0',
#   'accountId': '6_EqKrQed2OmljcmSCJihQNW0mobjLQAkCAZEaGABQZttw',
#   'puuid': 'wW-6ZmgvN8tw_FXHGgux5hR1aBryiWdzhys4iNMXtYoM3ZuOBnQFbSCBFI-vycO2m_pLlpvFj_gV6w',
#   'name': 'tommytomato52',
#   'profileIconId': 505,
#   'revisionDate': 1652732078000,
#   'summonerLevel': 188},
#  {'id': 'DkN9tDInFSY1kWalSs3UpdeKAjdvZdyF-8q18fXUPxGr2k0Ly27rLzBCOQ',
#   'accountId': 'VI5rNzWREdxPUKWlksePl4eVYxqLWInF8bbwlIikZWe59QhJPVlCyERF',
#   'puuid': '5FlOyAkuKi6rGlFfJDnlP41Nn0VADh-7uEuXjRysZBpxyJj1bzJdUDNg73A26MCCVQbeBhYVACAwpA',
#   'name': 'jjking9',
#   'profileIconId': 5340,
#   'revisionDate': 1652906448000,
#   'summonerLevel': 183},
#  {'id': 'Dg0TH4NpanJvZDAk99XXBHivrIM5WM5YdjmCpn5qST22CUg',
#   'accountId': 'diFbVU1Iz9KjcuQtqNNOtOeTfboK7FcewdKkAdwqu8iSFLU',
#   'puuid': 'JaJEMxRomUvOPKayf0Ad9pMWWvUAyq7UE8Vc99H4_SyNHObMDDuG_DfwOifnCcnlx59VKLB01-dQGQ',
#   'name': 'FrosFores',
#   'profileIconId': 3211,
#   'revisionDate': 1652817970000,
#   'summonerLevel': 165},
#  {'id': 'QKxGB4Y3LRhRLqU8HbHEYnAlhqgMJSyEmWMTFtfRClParWYP',
#   'accountId': 'fEpvoDF516UXH5Bo34F_bdrFDaDgL9asQu-hypXpW1HOlnYiCC-uDG_P',
#   'puuid': 'CxsHLQX2a0bvSP2j0R3Q2T0F-sBjhj4l7dVhw5cATAuuhWWm5439CQCdRV6yddl4YGcdQx4CeQm3Sg',
#   'name': 'RBOMLDR',
#   'profileIconId': 4779,
#   'revisionDate': 1652114675000,
#   'summonerLevel': 76},
#  {'id': '5utPRLI5c0PowiRs6dhwLfgIdUDf2sK4gu3Ias82RSdffmI',
#   'accountId': '-kDwGgBZ3h9p9lb76Wb9P67o7mFUyy_b1GZh6gf1ybYauA',
#   'puuid': 'mlRAzzxvm3ofXuq29Vhsz-4WYKA_f5Gjcj37Y8l-VOUF8DYsadU-AT0rwxp2bdX-l-8abgfFCbOg8A',
#   'name': 'Topo',
#   'profileIconId': 5170,
#   'revisionDate': 1652932873457,
#   'summonerLevel': 869},
#  {'id': 'rHnVA3trM2NSyUm7pHfCfVd4X41kD6nfTGSFfMMl2YlmEMk',
#   'accountId': 'ptuyU9iPBsYBM2M2Eu2d0j4L_M5mnQQ17UmsIIjGbqa6EQ',
#   'puuid': 'UEoTKyyuj-kfwWqpTOdqciDUSqCfMZriTeW7mdQEZcPXkRu_bZLSWaYSfFY5vIHaeh55pFlltnm00A',
#   'name': 'Messages',
#   'profileIconId': 5169,
#   'revisionDate': 1652860744000,
#   'summonerLevel': 384},
#  {'id': '3ip81TxpAN0KMI9T8XXXTk1nt0yjWIgM3zcYdqYJ6Sw9P3zz',
#   'accountId': 'WaGV3c8xUvEPvstc8bsNMInXJqMLJI8ObVHN4mBGUwzJC8XhGzMbQYhp',
#   'puuid': 'cmy7m1xOrpM6DmHJ97jM-l81RYza5ppgAZLyDexvlL3ubhH2Gr_u-Ez4UgX_CXQXV6pCEd-Lp6p6Nw',
#   'name': 'yukino cat',
#   'profileIconId': 4895,
#   'revisionDate': 1652926121813,
#   'summonerLevel': 340},
#  {'id': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb',
#   'accountId': 'zd3xHtQ8jehHZpCYw3RdU9hgu-3Qbkstv3GA1hCiGzbfVFmAj_HL28Wk',
#   'puuid': 'Js54dBF07DBtQtIVABk-8AI9RRt1H7hgAKHyATGcTowFseQhRzJqt__PPsEGC893MIqwPR4Yp3bINg',
#   'name': 'Airren',
#   'profileIconId': 5314,
#   'revisionDate': 1652638644000,
#   'summonerLevel': 167},
#  {'id': 'dgMcpMRc2quDh4657UI-86sWRPKeHwipqzYisryWsCab8E6c',
#   'accountId': 'gHiQt0pFcF6iNQW9FMoEW6XCkc5zdo688PapnuZEK6F8qrXdhzbtOwZ4',
#   'puuid': 'nwL3-HOXSpT4u1su-atzJuog1t0fcGcoBaOD_mJSHNM6CB7KCBx4RJSVO3Zw6Qu-_w0urv2KBKJ4vw',
#   'name': 'ScrubNoob',
#   'profileIconId': 5320,
#   'revisionDate': 1652566703000,
#   'summonerLevel': 167},
#  {'id': '6uYiNxO9lta5ao2p2sxKMbDu3KWn7_BjjfJ8QaPcz_Cw7RVR2TBPUVrdIw',
#   'accountId': 'Xed_7GtvvHxss9PPC7nsENzjuKPlAAGdeJkHm7hPXQLl6m9H_m2-Xi7t',
#   'puuid': 'xteqZkwQntndgNMO97dXIR5rSFnMnuMw998ULO6wxOa6mZ_uCZZ2adZ9QtPmXx__TtPLG-6uScFJYQ',
#   'name': 'Revengeee',
#   'profileIconId': 5271,
#   'revisionDate': 1652552849000,
#   'summonerLevel': 60}]

# %%
players10_challenger
# Out:
#            tier                              leagueId            queue  \
# 290  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 291  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 292  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 293  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 294  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 295  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 296  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 297  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 298  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
# 299  CHALLENGER  d609d862-7a3f-3f35-8c18-1fbc8198f70a  RANKED_SOLO_5x5
#
#                  name                                            entries  \
# 290  Swain's Villains  {'summonerId': 'rNT9BtqsZKf9t3CqkWw-DRL2bCALut...
# 291  Swain's Villains  {'summonerId': 'DkN9tDInFSY1kWalSs3UpdeKAjdvZd...
# 292  Swain's Villains  {'summonerId': 'Dg0TH4NpanJvZDAk99XXBHivrIM5WM...
# 293  Swain's Villains  {'summonerId': 'QKxGB4Y3LRhRLqU8HbHEYnAlhqgMJS...
# 294  Swain's Villains  {'summonerId': '5utPRLI5c0PowiRs6dhwLfgIdUDf2s...
# 295  Swain's Villains  {'summonerId': 'rHnVA3trM2NSyUm7pHfCfVd4X41kD6...
# 296  Swain's Villains  {'summonerId': '3ip81TxpAN0KMI9T8XXXTk1nt0yjWI...
# 297  Swain's Villains  {'summonerId': 'yAm4A6HE7fsZOfive9jHwCn3IGEmjU...
# 298  Swain's Villains  {'summonerId': 'dgMcpMRc2quDh4657UI-86sWRPKeHw...
# 299  Swain's Villains  {'summonerId': '6uYiNxO9lta5ao2p2sxKMbDu3KWn7_...
#
#                                             summonerId   summonerName  \
# 290    rNT9BtqsZKf9t3CqkWw-DRL2bCALutDlZHXjEpW_5Id9Mw0  tommytomato52
# 291  DkN9tDInFSY1kWalSs3UpdeKAjdvZdyF-8q18fXUPxGr2k...        jjking9
# 292    Dg0TH4NpanJvZDAk99XXBHivrIM5WM5YdjmCpn5qST22CUg      FrosFores
# 293   QKxGB4Y3LRhRLqU8HbHEYnAlhqgMJSyEmWMTFtfRClParWYP        RBOMLDR
# 294    5utPRLI5c0PowiRs6dhwLfgIdUDf2sK4gu3Ias82RSdffmI           Topo
# 295    rHnVA3trM2NSyUm7pHfCfVd4X41kD6nfTGSFfMMl2YlmEMk       Messages
# 296   3ip81TxpAN0KMI9T8XXXTk1nt0yjWIgM3zcYdqYJ6Sw9P3zz     yukino cat
# 297   yAm4A6HE7fsZOfive9jHwCn3IGEmjUmgDDA91DT7W4KXsIrb         Airren
# 298   dgMcpMRc2quDh4657UI-86sWRPKeHwipqzYisryWsCab8E6c      ScrubNoob
# 299  6uYiNxO9lta5ao2p2sxKMbDu3KWn7_BjjfJ8QaPcz_Cw7R...      Revengeee
#
#      leaguePoints rank  wins  losses  veteran  inactive  freshBlood  \
# 290           945    I   140     100    False     False       False
# 291           802    I   288     276     True     False       False
# 292           828    I   116      79    False     False        True
# 293          1020    I   132      94     True     False       False
# 294          1160    I   184     147     True     False       False
# 295           793    I   152     129    False     False        True
# 296           849    I   325     304    False     False       False
# 297           837    I   203     179    False     False       False
# 298          1055    I   212     175     True     False       False
# 299          1181    I   208     164     True     False       False
#
#      hotStreak  total_games
# 290      False          240
# 291      False          564
# 292      False          195
# 293      False          226
# 294      False          331
# 295      False          281
# 296      False          629
# 297       True          382
# 298      False          387
# 299      False          372

# %%
players10_challenger.total_games.min()
# Out:
# 195

# %%
players10_challenger.total_games[players10_challenger.summonerName == player_name]
# Out:
# 290    240
# 291    564
# 292    195
# 293    226
# 294    331
# 295    281
# 296    629
# 297    382
# 298    387
# 299    372
# Name: total_games, dtype: int64

# %% [markdown]
# # getting matchId

# %%
player_name= 'EricZYang'
player_region= 'NA1'.lower() #[BR1, EUN1, EUW1, JP1, KR, LA1, LA2, NA1, OC1, TR1, RU]  
player_routing= 'americas'
summoner= lol_watcher.summoner.by_name(player_region, player_name)
match_history= lol_watcher.match.matchlist_by_puuid(region= player_routing, puuid= summoner['puuid'],
                                                    queue= 420, 
                                                    start=0, count= 100) #this wrapper max count is 100

# %%
player_name= players10_challenger.summonerName
player_region= 'NA1'.lower()
player_routing= 'americas'
match_history = []

for player in player_name:
    summoner= lol_watcher.summoner.by_name(player_region, player)
    for games in players10_challenger.total_games:
        match_history.append(lol_watcher.match.matchlist_by_puuid(region= player_routing, puuid= summoner['puuid'],
                                                        queue= 420, 
                                                        start=0, count= 100))

# %% [markdown]
# If i want to grab all of the games.  look into try except!!! if cant figure out ask saad

# %%
len(match_history)
# Out:
# 100

# %%
all_matchIDs = sum(match_history, [])
all_matchIDs
# Out:
# ['NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  'NA1_4312336464',
#  'NA1_4312301344',
#  'NA1_4312277873',
#  'NA1_4312274898',
#  'NA1_4309912676',
#  'NA1_4309857532',
#  'NA1_4309863754',
#  'NA1_4309832477',
#  'NA1_4309810340',
#  'NA1_4305494850',
#  'NA1_4305419013',
#  'NA1_4305431634',
#  'NA1_4305345360',
#  'NA1_4304368580',
#  'NA1_4304323908',
#  'NA1_4304360419',
#  'NA1_4304274453',
#  'NA1_4303230613',
#  'NA1_4303149319',
#  'NA1_4303182642',
#  'NA1_4302157806',
#  'NA1_4296596254',
#  'NA1_4296591201',
#  'NA1_4296539027',
#  'NA1_4296532598',
#  'NA1_4296506712',
#  'NA1_4288226494',
#  'NA1_4288213762',
#  'NA1_4288211474',
#  'NA1_4281406469',
#  'NA1_4281421431',
#  'NA1_4281366742',
#  'NA1_4281363374',
#  'NA1_4279271796',
#  'NA1_4279216602',
#  'NA1_4279223002',
#  'NA1_4278026674',
#  'NA1_4278041449',
#  'NA1_4272459932',
#  'NA1_4272394461',
#  'NA1_4272358964',
#  'NA1_4270300237',
#  'NA1_4270186829',
#  'NA1_4270161658',
#  'NA1_4270108691',
#  'NA1_4268006040',
#  'NA1_4267992621',
#  'NA1_4267017490',
#  'NA1_4267029964',
#  'NA1_4266866680',
#  'NA1_4263948706',
#  'NA1_4263924076',
#  'NA1_4263908559',
#  'NA1_4263892783',
#  'NA1_4262202260',
#  'NA1_4262156289',
#  'NA1_4260068165',
#  'NA1_4260103279',
#  'NA1_4260031435',
#  'NA1_4259967511',
#  'NA1_4259954805',
#  'NA1_4259909413',
#  'NA1_4258856552',
#  'NA1_4258890922',
#  'NA1_4258818456',
#  'NA1_4258007763',
#  'NA1_4258024460',
#  'NA1_4258010024',
#  'NA1_4257966549',
#  'NA1_4257982811',
#  'NA1_4257959969',
#  'NA1_4256941046',
#  'NA1_4256868809',
#  'NA1_4256857276',
#  'NA1_4256873907',
#  'NA1_4256899893',
#  'NA1_4256254559',
#  'NA1_4256222778',
#  'NA1_4256168699',
#  'NA1_4256194051',
#  'NA1_4256159310',
#  'NA1_4255235896',
#  'NA1_4253442819',
#  'NA1_4253399036',
#  'NA1_4253395063',
#  'NA1_4253359249',
#  'NA1_4253319631',
#  'NA1_4253346017',
#  'NA1_4253314774',
#  'NA1_4252566188',
#  'NA1_4252553576',
#  'NA1_4251373330',
#  'NA1_4251318599',
#  'NA1_4251305127',
#  'NA1_4251302342',
#  'NA1_4251267765',
#  'NA1_4249554736',
#  'NA1_4249538885',
#  'NA1_4249517683',
#  'NA1_4248555619',
#  ...]

# %%
len(all_matchIDs)
# Out:
# 10000

# %%
len(set(all_matchIDs))
# Out:
# 954

# %%
unique_matchIDs = list(set(all_matchIDs))
unique_matchIDs
# Out:
# ['NA1_4311023233',
#  'NA1_4282636577',
#  'NA1_4276791572',
#  'NA1_4244560508',
#  'NA1_4308402469',
#  'NA1_4275341007',
#  'NA1_4303124926',
#  'NA1_4291448459',
#  'NA1_4303107864',
#  'NA1_4305735634',
#  'NA1_4300432105',
#  'NA1_4283838459',
#  'NA1_4274918927',
#  'NA1_4312243974',
#  'NA1_4282499605',
#  'NA1_4249538885',
#  'NA1_4250871233',
#  'NA1_4296596254',
#  'NA1_4274070046',
#  'NA1_4312304808',
#  'NA1_4257241639',
#  'NA1_4291501352',
#  'NA1_4246270353',
#  'NA1_4312760747',
#  'NA1_4295533588',
#  'NA1_4260068165',
#  'NA1_4300324497',
#  'NA1_4310657272',
#  'NA1_4276329286',
#  'NA1_4284807893',
#  'NA1_4267383305',
#  'NA1_4303182642',
#  'NA1_4308964639',
#  'NA1_4296539027',
#  'NA1_4276831039',
#  'NA1_4295380099',
#  'NA1_4291378103',
#  'NA1_4275398388',
#  'NA1_4289737718',
#  'NA1_4297694036',
#  'NA1_4305816693',
#  'NA1_4312290036',
#  'NA1_4309376696',
#  'NA1_4283832603',
#  'NA1_4273609962',
#  'NA1_4292158592',
#  'NA1_4293706776',
#  'NA1_4289326997',
#  'NA1_4299265670',
#  'NA1_4281754450',
#  'NA1_4312892360',
#  'NA1_4285393095',
#  'NA1_4278067562',
#  'NA1_4295540739',
#  'NA1_4311418335',
#  'NA1_4280333216',
#  'NA1_4284756820',
#  'NA1_4293813759',
#  'NA1_4306378945',
#  'NA1_4272358964',
#  'NA1_4246529899',
#  'NA1_4266217906',
#  'NA1_4284877133',
#  'NA1_4302589242',
#  'NA1_4255115439',
#  'NA1_4287119679',
#  'NA1_4309248567',
#  'NA1_4307272120',
#  'NA1_4306296618',
#  'NA1_4287127364',
#  'NA1_4302086089',
#  'NA1_4280288471',
#  'NA1_4309929537',
#  'NA1_4285298112',
#  'NA1_4257614856',
#  'NA1_4300734631',
#  'NA1_4262202260',
#  'NA1_4255452343',
#  'NA1_4302064147',
#  'NA1_4305359661',
#  'NA1_4284028927',
#  'NA1_4267710952',
#  'NA1_4252823152',
#  'NA1_4267017490',
#  'NA1_4299284299',
#  'NA1_4291460144',
#  'NA1_4285439698',
#  'NA1_4255132288',
#  'NA1_4312455087',
#  'NA1_4305783165',
#  'NA1_4306885171',
#  'NA1_4250984846',
#  'NA1_4307166182',
#  'NA1_4254976500',
#  'NA1_4282278161',
#  'NA1_4275695735',
#  'NA1_4311830772',
#  'NA1_4307768495',
#  'NA1_4300200276',
#  'NA1_4248563668',
#  'NA1_4283122289',
#  'NA1_4302841124',
#  'NA1_4306527581',
#  'NA1_4291302039',
#  'NA1_4288309796',
#  'NA1_4310323160',
#  'NA1_4273412877',
#  'NA1_4255099387',
#  'NA1_4256194051',
#  'NA1_4290936207',
#  'NA1_4296435107',
#  'NA1_4296438473',
#  'NA1_4300290642',
#  'NA1_4267513183',
#  'NA1_4304426547',
#  'NA1_4308356186',
#  'NA1_4311610811',
#  'NA1_4305214334',
#  'NA1_4287028752',
#  'NA1_4254538568',
#  'NA1_4284328737',
#  'NA1_4283137421',
#  'NA1_4254846821',
#  'NA1_4265127045']

# %%
# [ID.replace('NA1_','') for ID in unique_matchIDs]

# %% [markdown]
# # getting timeline json for one match

# %%
timeline_data = lol_watcher.match.timeline_by_match(region= player_routing, match_id= unique_matchIDs[1])

# %%
pd.DataFrame(timeline_data)
# Out:
#                                                         metadata  \
# dataVersion                                                    2
# matchId                                           NA1_4282636577
# participants   [hg-LP-ubgI7_EU_N8mWwJnlcn81yhf5uY9IFYagJ4BEKY...
# frameInterval                                                NaN
# frames                                                       NaN
# gameId                                                       NaN
#
#                                                             info
# dataVersion                                                  NaN
# matchId                                                      NaN
# participants   [{'participantId': 1, 'puuid': 'hg-LP-ubgI7_EU...
# frameInterval                                              60000
# frames         [{'events': [{'realTimestamp': 1650424946544, ...
# gameId                                                4282636577

# %%
pd.DataFrame(timeline_data)['info'][2]
# Out:
# [{'participantId': 1,
#   'puuid': 'hg-LP-ubgI7_EU_N8mWwJnlcn81yhf5uY9IFYagJ4BEKYFbAFKxqmvD4S9Omvofd7GlR5S7vuyyM4g'},
#  {'participantId': 2,
#   'puuid': 'vRU4-Hw9j28qZoSwdgnJ4Yb-In5Ese1thtyaNg2_wbuo1snJ50LX8oETfFlaLr-PeiHrYVJ61a_uaw'},
#  {'participantId': 3,
#   'puuid': '4hDu8mxm-kKJCCywhMhTYAL_-Rc7zioy43SCBu-WmX_D7f0_qj5gGUTJbumWWf3uzZBL6lCWFBWUDA'},
#  {'participantId': 4,
#   'puuid': 'EEtlBmlUSCYskyxVP2C6RtoQcUDxFdJQ-lYf2uEU24Z7pPV_DTG9a5v1QH9F1EpgEj6pFAzPgrsYVA'},
#  {'participantId': 5,
#   'puuid': 'H9CxukImYjRwK_O0OgkuArF5VAb5a5_T1eL4IQVcRLsEAs785Hy-qsjJAzzT9-Er9I_j8oqWYTpqPg'},
#  {'participantId': 6,
#   'puuid': 'mlRAzzxvm3ofXuq29Vhsz-4WYKA_f5Gjcj37Y8l-VOUF8DYsadU-AT0rwxp2bdX-l-8abgfFCbOg8A'},
#  {'participantId': 7,
#   'puuid': 'Tv4PMumLcvS3mITafWXJnVBED8gH55hNvdjNtdjIoif76VOwhU6kuSaFWjpIXCzSZOdPz-HLMDSLgw'},
#  {'participantId': 8,
#   'puuid': 'PRKLrD4opz2RmeOhTX-X2shJu1k1cCBGWwXs0bZ7C25EBocDhZNwMnVj_3UsXlYZNejsJ27mhgHqog'},
#  {'participantId': 9,
#   'puuid': 'QM2iLv5n1jHhHqlis0N8m-YfTtE1B420vrs_RtHtXL7YG-6SXF5t6OhB3xGgDpq77IRmsfjOLf5mRw'},
#  {'participantId': 10,
#   'puuid': 'tuDByWG34kRO-PKjTOgMs_mjRZjbsqUUcTCEsfT51lllxtnCkZgNMcLIFfKVwAV-7g2sfd5XK_g2_w'}]

# %%
pd.DataFrame(pd.DataFrame(timeline_data)['info'][4])
# Out:
#                                                events  \
# 0   [{'realTimestamp': 1650424946544, 'timestamp':...
# 1   [{'itemId': 2033, 'participantId': 8, 'timesta...
# 2   [{'creatorId': 10, 'timestamp': 86363, 'type':...
# 3   [{'level': 2, 'participantId': 2, 'timestamp':...
# 4   [{'creatorId': 5, 'timestamp': 181531, 'type':...
# 5   [{'creatorId': 1, 'timestamp': 243398, 'type':...
# 6   [{'itemId': 3145, 'participantId': 3, 'timesta...
# 7   [{'level': 6, 'participantId': 1, 'timestamp':...
# 8   [{'itemId': 1028, 'participantId': 1, 'timesta...
# 9   [{'level': 5, 'participantId': 4, 'timestamp':...
# 10  [{'itemId': 1036, 'participantId': 2, 'timesta...
# 11  [{'bounty': 0, 'killerId': 3, 'killerTeamId': ...
# 12  [{'level': 8, 'participantId': 2, 'timestamp':...
# 13  [{'assistingParticipantIds': [2, 5], 'bounty':...
# 14  [{'bounty': 0, 'buildingType': 'TOWER_BUILDING...
# 15  [{'itemId': 6660, 'participantId': 6, 'timesta...
# 16  [{'bounty': 0, 'buildingType': 'TOWER_BUILDING...
# 17  [{'level': 9, 'participantId': 5, 'timestamp':...
# 18  [{'itemId': 2420, 'participantId': 8, 'timesta...
# 19  [{'levelUpType': 'NORMAL', 'participantId': 3,...
# 20  [{'level': 13, 'participantId': 7, 'timestamp'...
# 21  [{'bounty': 350, 'buildingType': 'TOWER_BUILDI...
#
#                                     participantFrames  timestamp
# 0   {'1': {'championStats': {'abilityHaste': 0, 'a...          0
# 1   {'1': {'championStats': {'abilityHaste': 0, 'a...      60022
# 2   {'1': {'championStats': {'abilityHaste': 0, 'a...     120040
# 3   {'1': {'championStats': {'abilityHaste': 0, 'a...     180051
# 4   {'1': {'championStats': {'abilityHaste': 0, 'a...     240065
# 5   {'1': {'championStats': {'abilityHaste': 0, 'a...     300066
# 6   {'1': {'championStats': {'abilityHaste': 0, 'a...     360096
# 7   {'1': {'championStats': {'abilityHaste': 0, 'a...     420104
# 8   {'1': {'championStats': {'abilityHaste': 0, 'a...     480131
# 9   {'1': {'championStats': {'abilityHaste': 0, 'a...     540139
# 10  {'1': {'championStats': {'abilityHaste': 0, 'a...     600153
# 11  {'1': {'championStats': {'abilityHaste': 0, 'a...     660155
# 12  {'1': {'championStats': {'abilityHaste': 0, 'a...     720182
# 13  {'1': {'championStats': {'abilityHaste': 0, 'a...     780217
# 14  {'1': {'championStats': {'abilityHaste': 0, 'a...     840245
# 15  {'1': {'championStats': {'abilityHaste': 0, 'a...     900252
# 16  {'1': {'championStats': {'abilityHaste': 0, 'a...     960256
# 17  {'1': {'championStats': {'abilityHaste': 0, 'a...    1020279
# 18  {'1': {'championStats': {'abilityHaste': 0, 'a...    1080282
# 19  {'1': {'championStats': {'abilityHaste': 0, 'a...    1140292
# 20  {'1': {'championStats': {'abilityHaste': 0, 'a...    1200320
# 21  {'1': {'championStats': {'abilityHaste': 0, 'a...    1210815

# %%
timeline_data['info']['frames'][7]
# Out:
# {'events': [{'level': 6,
#    'participantId': 1,
#    'timestamp': 360934,
#    'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 1,
#    'skillSlot': 4,
#    'timestamp': 362667,
#    'type': 'SKILL_LEVEL_UP'},
#   {'level': 5, 'participantId': 2, 'timestamp': 364562, 'type': 'LEVEL_UP'},
#   {'level': 5, 'participantId': 7, 'timestamp': 365463, 'type': 'LEVEL_UP'},
#   {'creatorId': 9,
#    'timestamp': 366397,
#    'type': 'WARD_PLACED',
#    'wardType': 'YELLOW_TRINKET'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 2,
#    'skillSlot': 1,
#    'timestamp': 366529,
#    'type': 'SKILL_LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 7,
#    'skillSlot': 3,
#    'timestamp': 368134,
#    'type': 'SKILL_LEVEL_UP'},
#   {'level': 5, 'participantId': 3, 'timestamp': 371138, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 3,
#    'skillSlot': 1,
#    'timestamp': 371941,
#    'type': 'SKILL_LEVEL_UP'},
#   {'level': 4, 'participantId': 9, 'timestamp': 373672, 'type': 'LEVEL_UP'},
#   {'level': 4, 'participantId': 4, 'timestamp': 374704, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 4,
#    'skillSlot': 2,
#    'timestamp': 375604,
#    'type': 'SKILL_LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 9,
#    'skillSlot': 1,
#    'timestamp': 376774,
#    'type': 'SKILL_LEVEL_UP'},
#   {'itemId': 2010,
#    'participantId': 4,
#    'timestamp': 391291,
#    'type': 'ITEM_DESTROYED'},
#   {'level': 4, 'participantId': 10, 'timestamp': 391691, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 10,
#    'skillSlot': 1,
#    'timestamp': 392462,
#    'type': 'SKILL_LEVEL_UP'},
#   {'level': 6, 'participantId': 6, 'timestamp': 394861, 'type': 'LEVEL_UP'},
#   {'itemId': 2010,
#    'participantId': 2,
#    'timestamp': 396030,
#    'type': 'ITEM_DESTROYED'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 6,
#    'skillSlot': 4,
#    'timestamp': 400119,
#    'type': 'SKILL_LEVEL_UP'},
#   {'itemId': 2010,
#    'participantId': 2,
#    'timestamp': 404233,
#    'type': 'ITEM_DESTROYED'},
#   {'assistingParticipantIds': [7, 9, 10],
#    'bounty': 300,
#    'killStreakLength': 2,
#    'killerId': 8,
#    'position': {'x': 11906, 'y': 2786},
#    'shutdownBounty': 0,
#    'timestamp': 404400,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 7,
#      'physicalDamage': 144,
#      'spellName': 'xayahe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 7,
#      'physicalDamage': 202,
#      'spellName': 'xayahpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 7,
#      'physicalDamage': 12,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 7,
#      'physicalDamage': 28,
#      'spellName': 'xayahw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 9,
#      'physicalDamage': 115,
#      'spellName': 'xayahe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 9,
#      'physicalDamage': 16,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 10,
#      'physicalDamage': 110,
#      'spellName': 'xayahe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 10,
#      'physicalDamage': 22,
#      'spellName': 'xayahpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 13,
#      'spellName': 'sru_chaosminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 10,
#      'spellName': 'sru_chaosminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': False,
#      'magicDamage': 77,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggse',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 40,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 44,
#      'spellName': 'ziggsbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 129,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggsq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 85,
#      'spellName': 'sennapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 46,
#      'spellName': 'sennapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 89,
#      'spellName': 'sennabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 114,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'monkeykingnimbus',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 61,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 156,
#      'spellName': 'monkeykingbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 26,
#      'spellName': 'monkeykingdecoy',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 20,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'fizzw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 4,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'fizzbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 32,
#      'spellName': 'fizzbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 2,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'itemdarkcrystalflask',
#      'spellSlot': 6,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 4},
#   {'assistingParticipantIds': [8, 9, 10],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 7,
#    'position': {'x': 12128, 'y': 3008},
#    'shutdownBounty': 0,
#    'timestamp': 406289,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 85,
#      'name': 'Diana',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'dianateleport',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 51,
#      'name': 'Diana',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 127,
#      'name': 'Diana',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'dianaq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Diana',
#      'participantId': 7,
#      'physicalDamage': 41,
#      'spellName': 'dianabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Diana',
#      'participantId': 7,
#      'physicalDamage': 71,
#      'spellName': 'dianabasicattack',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 62,
#      'name': 'Diana',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'dianaorbs',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 40,
#      'name': 'Diana',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'dianapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 21,
#      'name': 'Diana',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'dianaorbs',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 99,
#      'spellName': 'sennaw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 49,
#      'spellName': 'sennapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'sennabasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 71,
#      'spellName': 'sennaq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 127,
#      'spellName': 'sennacritattack',
#      'spellSlot': 73,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 17,
#      'spellName': 'sru_chaosminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 14,
#      'spellName': 'sru_chaosminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 17,
#      'spellName': 'sru_chaosminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': False,
#      'magicDamage': 60,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggse',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 37,
#      'spellName': 'ziggsbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 91,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 124,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggsq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 34,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggsw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 73,
#      'spellName': 'monkeykingdoubleattack',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 71,
#      'spellName': 'monkeykingbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 110,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'monkeykingnimbus',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 44,
#      'spellName': 'monkeykingdecoy',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 54,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 35,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'fizzw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 46,
#      'spellName': 'fizzbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 3},
#   {'assistingParticipantIds': [2, 3, 4],
#    'bounty': 300,
#    'killStreakLength': 2,
#    'killerId': 5,
#    'position': {'x': 11912, 'y': 3113},
#    'shutdownBounty': 0,
#    'timestamp': 406488,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 2,
#      'physicalDamage': 70,
#      'spellName': 'monkeykingbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 85,
#      'name': 'MonkeyKing',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'monkeykingnimbus',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 2,
#      'physicalDamage': 57,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 2,
#      'physicalDamage': 73,
#      'spellName': 'monkeykingbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 145,
#      'name': 'SRU_Gromp',
#      'participantId': 0,
#      'physicalDamage': 0,
#      'spellName': 'sru_grompbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MONSTER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lucian',
#      'participantId': 2,
#      'physicalDamage': 95,
#      'spellName': 'lucianq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lucian',
#      'participantId': 2,
#      'physicalDamage': 55,
#      'spellName': 'lucianbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 25,
#      'name': 'Lucian',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'lucianbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 13,
#      'name': 'Lucian',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'itemdarkcrystalflask',
#      'spellSlot': 7,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 61,
#      'name': 'Lucian',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'lucianw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 4,
#      'physicalDamage': 144,
#      'spellName': 'xayahe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 4,
#      'physicalDamage': 202,
#      'spellName': 'xayahpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 4,
#      'physicalDamage': 12,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Xayah',
#      'participantId': 4,
#      'physicalDamage': 28,
#      'spellName': 'xayahw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 85,
#      'name': 'Diana',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'dianateleport',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 51,
#      'name': 'Diana',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 127,
#      'name': 'Diana',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'dianaq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Diana',
#      'participantId': 3,
#      'physicalDamage': 41,
#      'spellName': 'dianabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Diana',
#      'participantId': 3,
#      'physicalDamage': 71,
#      'spellName': 'dianabasicattack',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 62,
#      'name': 'Diana',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'dianaorbs',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 40,
#      'name': 'Diana',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'dianapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 74,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 16,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 7},
#   {'itemId': 1036,
#    'participantId': 4,
#    'timestamp': 408822,
#    'type': 'ITEM_PURCHASED'},
#   {'assistingParticipantIds': [8, 10],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 9,
#    'position': {'x': 11100, 'y': 3931},
#    'shutdownBounty': 0,
#    'timestamp': 410693,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 59,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'lucianpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 248,
#      'spellName': 'lucianpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 65,
#      'spellName': 'lucianbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 19,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'lucianbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 51,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 62,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 122,
#      'spellName': 'lucianpassiveattack',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 17,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'itemdarkcrystalflask',
#      'spellSlot': 7,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lucian',
#      'participantId': 8,
#      'physicalDamage': 141,
#      'spellName': 'lucianq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lucian',
#      'participantId': 10,
#      'physicalDamage': 119,
#      'spellName': 'lucianq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 5,
#      'name': 'Lucian',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'itemdarkcrystalflask',
#      'spellSlot': 7,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 70,
#      'spellName': 'monkeykingbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 85,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'monkeykingnimbus',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 57,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'MonkeyKing',
#      'participantId': 7,
#      'physicalDamage': 73,
#      'spellName': 'monkeykingbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionRanged',
#      'participantId': 0,
#      'physicalDamage': 21,
#      'spellName': 'sru_chaosminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionRanged',
#      'participantId': 0,
#      'physicalDamage': 31,
#      'spellName': 'sru_chaosminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 182,
#      'spellName': 'sennapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 91,
#      'spellName': 'sennapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 79,
#      'spellName': 'sennaq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 92,
#      'spellName': 'sennabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 39,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggse',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 102,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggsq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 35,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ziggspassivebuff',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 44,
#      'spellName': 'ziggspassivebuff',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ziggs',
#      'participantId': 9,
#      'physicalDamage': 44,
#      'spellName': 'ziggsbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 9,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'itemdarkcrystalflask',
#      'spellSlot': 6,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 25,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'fizzbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 101,
#      'spellName': 'fizzbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 49,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 52,
#      'spellName': 'fizzq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 2},
#   {'level': 6, 'participantId': 8, 'timestamp': 410693, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 8,
#    'skillSlot': 4,
#    'timestamp': 411523,
#    'type': 'SKILL_LEVEL_UP'},
#   {'assistingParticipantIds': [8, 9],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 10,
#    'position': {'x': 10936, 'y': 3718},
#    'shutdownBounty': 100,
#    'timestamp': 411725,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 8,
#      'physicalDamage': 95,
#      'spellName': 'yuumip',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 5,
#      'trueDamage': 150,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 11,
#      'name': 'Yuumi',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 116,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'SRUAP_Turret_Chaos1',
#      'participantId': 0,
#      'physicalDamage': 398,
#      'spellName': 'sruap_turret_chaos1basicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'TOWER'},
#     {'basic': False,
#      'magicDamage': 43,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'fizzw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 28,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 33,
#      'spellName': 'fizzq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 7,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'itemdarkcrystalflask',
#      'spellSlot': 6,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 28,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'fizzbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 7,
#      'spellName': 'fizzbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Fizz',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 120,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 17,
#      'spellName': 'sennapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Senna',
#      'participantId': 10,
#      'physicalDamage': 89,
#      'spellName': 'sennabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 5},
#   {'level': 5, 'participantId': 9, 'timestamp': 414290, 'type': 'LEVEL_UP'},
#   {'itemId': 3067,
#    'participantId': 7,
#    'timestamp': 416101,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 2031,
#    'participantId': 7,
#    'timestamp': 416933,
#    'type': 'ITEM_SOLD'},
#   {'itemId': 1036,
#    'participantId': 7,
#    'timestamp': 417567,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 3067,
#    'participantId': 5,
#    'timestamp': 418906,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 4642,
#    'participantId': 5,
#    'timestamp': 419305,
#    'type': 'ITEM_PURCHASED'}],
#  'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 47,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 100,
#     'attackSpeed': 123,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 10,
#     'cooldownReduction': 0,
#     'health': 764,
#     'healthMax': 950,
#     'healthRegen': 21,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 44,
#     'movementSpeed': 350,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 320,
#     'powerMax': 594,
#     'powerRegen': 20,
#     'spellVamp': 0},
#    'currentGold': 565,
#    'damageStats': {'magicDamageDone': 1947,
#     'magicDamageDoneToChampions': 306,
#     'magicDamageTaken': 1391,
#     'physicalDamageDone': 8611,
#     'physicalDamageDoneToChampions': 887,
#     'physicalDamageTaken': 735,
#     'totalDamageDone': 10558,
#     'totalDamageDoneToChampions': 1193,
#     'totalDamageTaken': 2126,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 6,
#    'minionsKilled': 45,
#    'participantId': 1,
#    'position': {'x': 7191, 'y': 7846},
#    'timeEnemySpentControlled': 16328,
#    'totalGold': 2115,
#    'xp': 2979},
#   '2': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 37,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 76,
#     'attackSpeed': 120,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 0,
#     'healthMax': 836,
#     'healthRegen': 11,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 64,
#     'movementSpeed': 360,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 534,
#     'powerMax': 616,
#     'powerRegen': 20,
#     'spellVamp': 0},
#    'currentGold': 581,
#    'damageStats': {'magicDamageDone': 1217,
#     'magicDamageDoneToChampions': 469,
#     'magicDamageTaken': 813,
#     'physicalDamageDone': 9990,
#     'physicalDamageDoneToChampions': 2079,
#     'physicalDamageTaken': 2100,
#     'totalDamageDone': 11208,
#     'totalDamageDoneToChampions': 2548,
#     'totalDamageTaken': 2990,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 76},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 5,
#    'minionsKilled': 36,
#    'participantId': 2,
#    'position': {'x': 11100, 'y': 3931},
#    'timeEnemySpentControlled': 7407,
#    'totalGold': 1841,
#    'xp': 2052},
#   '3': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 54,
#     'armor': 61,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 66,
#     'attackSpeed': 146,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 0,
#     'healthMax': 1013,
#     'healthRegen': 18,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 35,
#     'movementSpeed': 345,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 213,
#     'powerMax': 452,
#     'powerRegen': 20,
#     'spellVamp': 0},
#    'currentGold': 553,
#    'damageStats': {'magicDamageDone': 16649,
#     'magicDamageDoneToChampions': 1017,
#     'magicDamageTaken': 1266,
#     'physicalDamageDone': 5315,
#     'physicalDamageDoneToChampions': 343,
#     'physicalDamageTaken': 3481,
#     'totalDamageDone': 24037,
#     'totalDamageDoneToChampions': 1368,
#     'totalDamageTaken': 4748,
#     'trueDamageDone': 2072,
#     'trueDamageDoneToChampions': 8,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 36,
#    'level': 5,
#    'minionsKilled': 1,
#    'participantId': 3,
#    'position': {'x': 12128, 'y': 3008},
#    'timeEnemySpentControlled': 48285,
#    'totalGold': 2838,
#    'xp': 1881},
#   '4': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 37,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 113,
#     'attackSpeed': 118,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 789,
#     'healthMax': 789,
#     'healthRegen': 9,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 503,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 1006,
#     'powerMax': 1006,
#     'powerRegen': 19,
#     'spellVamp': 0},
#    'currentGold': 71,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 1474,
#     'physicalDamageDone': 7945,
#     'physicalDamageDoneToChampions': 2371,
#     'physicalDamageTaken': 1970,
#     'totalDamageDone': 7945,
#     'totalDamageDoneToChampions': 2371,
#     'totalDamageTaken': 3445,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 4,
#    'minionsKilled': 23,
#    'participantId': 4,
#    'position': {'x': 2232, 'y': 687},
#    'timeEnemySpentControlled': 1299,
#    'totalGold': 2071,
#    'xp': 1326},
#   '5': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 46,
#     'armor': 34,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 64,
#     'attackSpeed': 103,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 0,
#     'healthMax': 906,
#     'healthRegen': 17,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 33,
#     'movementSpeed': 330,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 259,
#     'powerMax': 739,
#     'powerRegen': 44,
#     'spellVamp': 0},
#    'currentGold': 425,
#    'damageStats': {'magicDamageDone': 1093,
#     'magicDamageDoneToChampions': 809,
#     'magicDamageTaken': 424,
#     'physicalDamageDone': 1649,
#     'physicalDamageDoneToChampions': 803,
#     'physicalDamageTaken': 1134,
#     'totalDamageDone': 2962,
#     'totalDamageDoneToChampions': 1833,
#     'totalDamageTaken': 1678,
#     'trueDamageDone': 220,
#     'trueDamageDoneToChampions': 220,
#     'trueDamageTaken': 120},
#    'goldPerSecond': 20,
#    'jungleMinionsKilled': 0,
#    'level': 5,
#    'minionsKilled': 7,
#    'participantId': 5,
#    'position': {'x': 10936, 'y': 3718},
#    'timeEnemySpentControlled': 9586,
#    'totalGold': 2676,
#    'xp': 2114},
#   '6': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 18,
#     'armor': 75,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 77,
#     'attackSpeed': 113,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 1074,
#     'healthMax': 1079,
#     'healthRegen': 18,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 32,
#     'movementSpeed': 360,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 570,
#     'powerMax': 867,
#     'powerRegen': 18,
#     'spellVamp': 0},
#    'currentGold': 612,
#    'damageStats': {'magicDamageDone': 3222,
#     'magicDamageDoneToChampions': 1461,
#     'magicDamageTaken': 516,
#     'physicalDamageDone': 5064,
#     'physicalDamageDoneToChampions': 96,
#     'physicalDamageTaken': 1130,
#     'totalDamageDone': 8287,
#     'totalDamageDoneToChampions': 1557,
#     'totalDamageTaken': 1647,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 6,
#    'minionsKilled': 34,
#    'participantId': 6,
#    'position': {'x': 2916, 'y': 13188},
#    'timeEnemySpentControlled': 78533,
#    'totalGold': 1812,
#    'xp': 2745},
#   '7': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 47,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 104,
#     'attackSpeed': 131,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 301,
#     'healthMax': 1047,
#     'healthRegen': 19,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 345,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 143,
#     'powerMax': 500,
#     'powerRegen': 20,
#     'spellVamp': 0},
#    'currentGold': 108,
#    'damageStats': {'magicDamageDone': 8883,
#     'magicDamageDoneToChampions': 528,
#     'magicDamageTaken': 1270,
#     'physicalDamageDone': 13792,
#     'physicalDamageDoneToChampions': 1419,
#     'physicalDamageTaken': 3826,
#     'totalDamageDone': 25131,
#     'totalDamageDoneToChampions': 1979,
#     'totalDamageTaken': 5096,
#     'trueDamageDone': 2456,
#     'trueDamageDoneToChampions': 32,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 40,
#    'level': 5,
#    'minionsKilled': 0,
#    'participantId': 7,
#    'position': {'x': 11912, 'y': 3113},
#    'timeEnemySpentControlled': 101022,
#    'totalGold': 2823,
#    'xp': 2268},
#   '8': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 113,
#     'armor': 35,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 69,
#     'attackSpeed': 112,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 394,
#     'healthMax': 997,
#     'healthRegen': 125,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 44,
#     'movementSpeed': 360,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 463,
#     'powerMax': 463,
#     'powerRegen': 80,
#     'spellVamp': 0},
#    'currentGold': 1095,
#    'damageStats': {'magicDamageDone': 6057,
#     'magicDamageDoneToChampions': 865,
#     'magicDamageTaken': 511,
#     'physicalDamageDone': 3721,
#     'physicalDamageDoneToChampions': 895,
#     'physicalDamageTaken': 2222,
#     'totalDamageDone': 9943,
#     'totalDamageDoneToChampions': 1924,
#     'totalDamageTaken': 2884,
#     'trueDamageDone': 164,
#     'trueDamageDoneToChampions': 164,
#     'trueDamageTaken': 150},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 6,
#    'minionsKilled': 33,
#    'participantId': 8,
#    'position': {'x': 8815, 'y': 4731},
#    'timeEnemySpentControlled': 28250,
#    'totalGold': 3135,
#    'xp': 2469},
#   '9': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 53,
#     'armor': 38,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 63,
#     'attackSpeed': 106,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 724,
#     'healthMax': 890,
#     'healthRegen': 16,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 31,
#     'movementSpeed': 325,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 909,
#     'powerMax': 1478,
#     'powerRegen': 20,
#     'spellVamp': 0},
#    'currentGold': 904,
#    'damageStats': {'magicDamageDone': 8650,
#     'magicDamageDoneToChampions': 2138,
#     'magicDamageTaken': 461,
#     'physicalDamageDone': 2595,
#     'physicalDamageDoneToChampions': 523,
#     'physicalDamageTaken': 1693,
#     'totalDamageDone': 11246,
#     'totalDamageDoneToChampions': 2661,
#     'totalDamageTaken': 2233,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 78},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 5,
#    'minionsKilled': 29,
#    'participantId': 9,
#    'position': {'x': 11843, 'y': 2445},
#    'timeEnemySpentControlled': 50176,
#    'totalGold': 2664,
#    'xp': 1840},
#   '10': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 41,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 117,
#     'attackSpeed': 121,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 661,
#     'healthMax': 699,
#     'healthRegen': 9,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 39,
#     'movementSpeed': 355,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 451,
#     'powerMax': 451,
#     'powerRegen': 31,
#     'spellVamp': 0},
#    'currentGold': 929,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 388,
#     'physicalDamageDone': 3695,
#     'physicalDamageDoneToChampions': 2881,
#     'physicalDamageTaken': 2114,
#     'totalDamageDone': 3695,
#     'totalDamageDoneToChampions': 2881,
#     'totalDamageTaken': 2502,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 20,
#    'jungleMinionsKilled': 0,
#    'level': 4,
#    'minionsKilled': 1,
#    'participantId': 10,
#    'position': {'x': 11784, 'y': 2446},
#    'timeEnemySpentControlled': 69947,
#    'totalGold': 2829,
#    'xp': 1612}},
#  'timestamp': 420104}

# %% [markdown]
# game = `time = lol_watcher.match.timeline_by_match(region= player_routing, match_id= 'matchId')`  => `pd.DataFrame(pd.DataFrame(time)['info'][4])`

# %% [markdown]
# # Kills from each player during a match

# %%
def getKills(game):
    kills = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'CHAMPION_KILL':
                kills.append(event) 
    kills_df = pd.DataFrame(kills)
    kills_count = kills_df[['killerId', 'victimId']].groupby(by='killerId', axis=0).count()
    return kills_count

# %%
getKills(timeline_data)
# Out:
#           victimId
# killerId
# 1                1
# 2                1
# 3                5
# 4                4
# 5                4
# 6                3
# 7                5
# 8                5
# 9                4
# 10               6

# %% [markdown]
# # VisionScore from each player during a match

# %% [markdown]
# Cannot calculate vision score but will have a supplemental.

# %%
wards = []
def getWardsPlaced(game):
    wards = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'WARD_PLACED':
                wards.append(event) 
    return wards

# %%
wards_df = pd.DataFrame(getWardsPlaced(timeline_data))
wards_df = wards_df[wards_df.wardType != 'UNDEFINED']
wards_count = wards_df[['creatorId', 'type']].groupby(by='creatorId', axis=0).count()
wards_count.index.rename('participantId',inplace=True)
wards_count.rename(columns={'type':'wards_placed'}, inplace=True)
wards_count.reset_index(inplace=True)

# %%
wardsK = []
def getWardsKilled(game):
    wardsK = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'WARD_KILL':
                wardsK.append(event) 
    return wardsK

# %%
wardsK_df = pd.DataFrame(getWardsKilled(timeline_data))
wardsK_df = wardsK_df[wardsK_df.wardType != 'UNDEFINED']
wardsK_count = wardsK_df[['killerId', 'type']].groupby(by='killerId', axis=0).count()
wardsK_count.index.rename('participantId',inplace=True)
wardsK_count.rename(columns={'type':'wards_destroyed'}, inplace=True)
wardsK_count.reset_index(inplace=True)

# %%
tot_wards_df = wards_count.set_index('participantId').join(wardsK_count.set_index('participantId'), how='left').fillna(0)
tot_wards_df.wards_destroyed = tot_wards_df.wards_destroyed.astype(int)
tot_wards_df['calc_vision_score'] = tot_wards_df.wards_placed + tot_wards_df.wards_destroyed
tot_wards_df
# Out:
#                wards_placed  wards_destroyed  calc_vision_score
# participantId
# 1                         2                0                  2
# 2                         4                0                  4
# 3                         3                1                  4
# 4                         4                0                  4
# 5                        10                0                 10
# 6                         6                0                  6
# 7                         3                0                  3
# 9                         5                1                  6
# 10                       10                2                 12

# %% [markdown]
# # get vision score comparison for vision = place + killed vs end of game vision score.  place+killed should equal the total timeline

# %%
def getVisionScore(game):
    wardsK = defaultdict(int)
    wardsP = defaultdict(int)
    wardinfo = [wardsP, wardsK]
    
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if ((event['type'] == 'WARD_KILL') and (event['wardType'] != 'UNDEFINED')) : 
                if event['killerId'] in wardsK: 
                    wardsK[event['killerId']] += 1
                else:
                    wardsK[event['killerId']] =1
            elif ((event['type'] == 'WARD_PLACED') and (event['wardType'] != 'UNDEFINED')) :
                if event['creatorId'] in wardsP: 
                    wardsP[event['creatorId']] += 1
                else:
                    wardsP[event['creatorId']] = 1 
    wardinfo_df = pd.DataFrame(wardinfo).T.sort_index().rename(columns={0:'wards_placed',1:'wards_destroyed'}).fillna(0)
    wardinfo_df['VisionScore'] = wardinfo_df.wards_placed + wardinfo_df.wards_destroyed
    return wardinfo_df[['VisionScore']]

# %%
getVisionScore(timeline_data)
# Out:
#     VisionScore
# 1           2.0
# 2           4.0
# 3           4.0
# 4           4.0
# 5          10.0
# 6           6.0
# 7           3.0
# 8           3.0
# 9           6.0
# 10         12.0

# %%
wardsK = defaultdict(int)
def getWardsKilled(game):
    for frame in game['info']['frames']:
        for event in frame['events']:
            if ((event['type'] == 'WARD_KILL') and (event['wardType'] != 'UNDEFINED')) : 
                if event['killerId'] in wardsK: 
                    wardsK[event['killerId']] += 1
                else:
                    wardsK[event['killerId']] =1
    return pd.DataFrame.from_dict(wardsK, orient='index', columns=['count']).sort_index()

# %%
getWardsKilled_df = getWardsKilled(timeline_data)
getWardsKilled_df
# Out:
#     count
# 1       2
# 2       1
# 3       1
# 4       1
# 5       1
# 7       1
# 8       3
# 9       1
# 10      8

# %%
tot_wards_df = wards_count.set_index('participantId').join(wardsK_count.set_index('participantId'), how='left').fillna(0)
tot_wards_df.wards_destroyed = tot_wards_df.wards_destroyed.astype(int)
tot_wards_df['calc_vision_score'] = tot_wards_df.wards_placed + tot_wards_df.wards_destroyed
tot_wards_df
# Out:
#                wards_placed  wards_destroyed  calc_vision_score
# participantId
# 1                         2                0                  2
# 2                         4                0                  4
# 3                         3                1                  4
# 4                         4                0                  4
# 5                        10                0                 10
# 6                         6                0                  6
# 7                         3                0                  3
# 9                         5                1                  6
# 10                       10                2                 12

# %%
resp = requests.get(f'https://americas.api.riotgames.com/lol/match/v5/matches/{unique_matchIDs[0]}?api_key={api_keys}')

# %%
game_time_mins = pd.DataFrame(resp.json())['info']['gameDuration'] / 60

# %%
pd.DataFrame(resp.json())['info'][2][0]
# Out:
# {'assists': 12,
#  'baronKills': 0,
#  'bountyLevel': 3,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 284,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 1.5,
#   'baronBuffGoldAdvantageOverThreshold': 1,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.014434627930078905,
#   'controlWardsPlaced': 1,
#   'damagePerMinute': 784.8676051049456,
#   'damageTakenOnTeamPercentage': 0.2425431177618453,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 3,
#   'dodgeSkillShotsSmallWindow': 116,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earliestBaron': 1330.347260358595,
#   'earlyLaningPhaseGoldExpAdvantage': 1,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 0,
#   'enemyJungleMonsterKills': 1.5,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilledTime': 745.1096381168161,
#   'flawlessAces': 0,
#   'fullTeamTakedown': 2,
#   'gameLength': 1478.1010022637893,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 545.4596749157834,
#   'hadAfkTeammate': 0,
#   'hadOpenNexus': 0,
#   'highestChampionDamage': 1,
#   'immobilizeAndKillWithAlly': 0,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 0,
#   'kda': 5.666666666666667,
#   'killAfterHiddenWithAlly': 1,
#   'killParticipation': 1.2142857142857142,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 1,
#   'killsNearEnemyTurret': 3,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 0,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 0,
#   'landSkillShotsEarlyGame': 0,
#   'laneMinionsFirst10Minutes': 79,
#   'laningPhaseGoldExpAdvantage': 1,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxCsAdvantageOnLaneOpponent': 86.24999994039536,
#   'maxKillDeficit': 0,
#   'maxLevelLeadLaneOpponent': 4,
#   'moreEnemyJungleThanOpponent': -113.00000005960464,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 1,
#   'multikillsAfterAggressiveFlash': 1,
#   'mythicItemUsed': 3078,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 0,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 13,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'shortestTimeToAceFromFirstTakedown': 25.930241451866323,
#   'skillshotsDodged': 47,
#   'skillshotsHit': 0,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 2,
#   'soloTurretsLategame': 1,
#   'stealthWardsPlaced': 5,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 4,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 17,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 8,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 1,
#   'teamDamagePercentage': 0.3359309826476148,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 2,
#   'threeWardsOneSweeperCount': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 4,
#   'turretTakedowns': 3,
#   'turretsTakenWithRiftHerald': 5,
#   'twentyMinionsIn3SecondsCount': 0,
#   'unseenRecalls': 0,
#   'visionScoreAdvantageLaneOpponent': 0.01585853099822998,
#   'visionScorePerMinute': 0.685303821270874,
#   'wardTakedowns': 3,
#   'wardTakedownsBefore20M': 3,
#   'wardsGuarded': 1},
#  'champExperience': 14841,
#  'champLevel': 16,
#  'championId': 41,
#  'championName': 'Gangplank',
#  'championTransform': 0,
#  'consumablesPurchased': 1,
#  'damageDealtToBuildings': 7665,
#  'damageDealtToObjectives': 12577,
#  'damageDealtToTurrets': 7665,
#  'damageSelfMitigated': 14850,
#  'deaths': 3,
#  'detectorWardsPlaced': 1,
#  'doubleKills': 1,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'firstBloodAssist': True,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'goldEarned': 13437,
#  'goldSpent': 13308,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 0,
#  'inhibitorsLost': 0,
#  'item0': 2033,
#  'item1': 3078,
#  'item2': 3047,
#  'item3': 6609,
#  'item4': 3156,
#  'item5': 3110,
#  'item6': 3363,
#  'itemsPurchased': 24,
#  'killingSprees': 1,
#  'kills': 5,
#  'lane': 'TOP',
#  'largestCriticalStrike': 0,
#  'largestKillingSpree': 3,
#  'largestMultiKill': 2,
#  'longestTimeSpentLiving': 628,
#  'magicDamageDealt': 8389,
#  'magicDamageDealtToChampions': 4176,
#  'magicDamageTaken': 3610,
#  'neutralMinionsKilled': 5,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8437, 'var1': 699, 'var2': 529, 'var3': 0},
#      {'perk': 8446, 'var1': 2261, 'var2': 0, 'var3': 0},
#      {'perk': 8473, 'var1': 823, 'var2': 0, 'var3': 0},
#      {'perk': 8451, 'var1': 199, 'var2': 0, 'var3': 0}],
#     'style': 8400},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#      {'perk': 8352, 'var1': 267, 'var2': 812, 'var3': 545}],
#     'style': 8300}]},
#  'physicalDamageDealt': 145006,
#  'physicalDamageDealtToChampions': 10935,
#  'physicalDamageTaken': 14427,
#  'profileIcon': 4779,
#  'puuid': 'CxsHLQX2a0bvSP2j0R3Q2T0F-sBjhj4l7dVhw5cATAuuhWWm5439CQCdRV6yddl4YGcdQx4CeQm3Sg',
#  'quadraKills': 0,
#  'riotIdName': '',
#  'riotIdTagline': '',
#  'role': 'SOLO',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 157,
#  'spell2Casts': 23,
#  'spell3Casts': 98,
#  'spell4Casts': 6,
#  'summoner1Casts': 3,
#  'summoner1Id': 4,
#  'summoner2Casts': 3,
#  'summoner2Id': 12,
#  'summonerId': 'QKxGB4Y3LRhRLqU8HbHEYnAlhqgMJSyEmWMTFtfRClParWYP',
#  'summonerLevel': 74,
#  'summonerName': 'RBOMLDR',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 10,
#  'timePlayed': 1478,
#  'totalDamageDealt': 169437,
#  'totalDamageDealtToChampions': 19335,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 19235,
#  'totalHeal': 5246,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 229,
#  'totalTimeCCDealt': 257,
#  'totalTimeSpentDead': 98,
#  'totalUnitsHealed': 1,
#  'tripleKills': 0,
#  'trueDamageDealt': 16041,
#  'trueDamageDealtToChampions': 4223,
#  'trueDamageTaken': 1197,
#  'turretKills': 1,
#  'turretTakedowns': 3,
#  'turretsLost': 2,
#  'unrealKills': 0,
#  'visionScore': 16,
#  'visionWardsBoughtInGame': 1,
#  'wardsKilled': 3,
#  'wardsPlaced': 8,
#  'win': True}

# %%
wards = []
def getWardsPlaced(game):
    wards = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'WARD_PLACED':
                wards.append(event) 
    return wards

# %%
visionpermin = []
for vision in pd.DataFrame(resp.json())['info'][2]:
    visionpermin.append(vision['challenges']['visionScorePerMinute'])

vision15calc = []    
for time in visionpermin:
    vision15calc.append(time*15)
       
    
visionTot = []    
for time in visionpermin:
    visionTot.append(time*game_time_mins)
# Out:
#           0
# 0  0.685304
# 1  1.471639
# 2  0.911044
# 3  0.978961
# 4  2.107919
# 5  0.674606
# 6  1.020172
# 7  0.902372
# 8  1.238541
# 9  1.793829

# %%
visionScore = []
for vision in pd.DataFrame(resp.json())['info'][2]:
    visionScore.append(vision['visionScore'])

# %%
tot_wards_df
# Out:
#                wards_placed  wards_destroyed  calc_vision_score
# participantId
# 1                         2                0                  2
# 2                         4                0                  4
# 3                         3                1                  4
# 4                         4                0                  4
# 5                        10                0                 10
# 6                         6                0                  6
# 7                         3                0                  3
# 9                         5                1                  6
# 10                       10                2                 12

# %%
tot_wards_df['vision15calc'] = vision15calc
tot_wards_df['visionTot'] = visionTot
tot_wards_df['visionScore'] = visionScore
tot_wards_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8460/2422542856.py in <module>
# ----> 1 tot_wards_df['vision15calc'] = vision15calc
#       2 tot_wards_df['visionTot'] = visionTot
#       3 tot_wards_df['visionScore'] = visionScore
#       4 tot_wards_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (10) does not match length of index (9)

# %%
tot_wards_df.corr()
# Out:
#                    wards_placed  wards_destroyed  calc_vision_score
# wards_placed           1.000000         0.414955           0.979940
# wards_destroyed        0.414955         1.000000           0.587957
# calc_vision_score      0.979940         0.587957           1.000000

# %% [markdown]
# # getAssists Function

# %%
def getAssists(game):
    assists = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'CHAMPION_KILL':
                assists.append(event) 
    assists_df = pd.DataFrame(assists).dropna()   
    assists_occured = assists_df.assistingParticipantIds
    assists_player_df = defaultdict(int)
    for assist in assists_occured:
        for death in assist:
            if death in assists_player_df:
                assists_player_df[death] += 1
            else:
                assists_player_df[death] = 1                                  
    return assists_player_df

# %%
getAssists(timeline_data)
# Out:
# defaultdict(int, {7: 5, 1: 3, 9: 7, 4: 6, 10: 6, 8: 6, 2: 5, 3: 3, 5: 6, 6: 1})

# %%
# def getAssists(game):
#     assists = []
#     for frame in game['info']['frames'][0:16]:
#         for event in frame['events']:
#             if event['type'] == 'CHAMPION_KILL':
#                 assists.append(event) 
#     return pd.DataFrame(assists).dropna()

# %%
# getAssists(timeline_data).head()

# %%
# assists_df = getAssists(timeline_data).assistingParticipantIds
# assists_df

# %%
# assists_player_df = defaultdict(int)
# for assist in assists_df:
#     for death in assist:
#         if death in assists_player_df:
#             assists_player_df[death] += 1
#         else:
#             assists_player_df[death] = 1
# assists_player_df

# %%
diff_types = []
for minute in pd.DataFrame(pd.DataFrame(timeline_data)['info'][4])['events']:
    for types in minute:
        diff_types.append(types['type'])
set(diff_types)
# Out:
# {'BUILDING_KILL',
#  'CHAMPION_KILL',
#  'CHAMPION_SPECIAL_KILL',
#  'ELITE_MONSTER_KILL',
#  'GAME_END',
#  'ITEM_DESTROYED',
#  'ITEM_PURCHASED',
#  'ITEM_SOLD',
#  'ITEM_UNDO',
#  'LEVEL_UP',
#  'OBJECTIVE_BOUNTY_PRESTART',
#  'PAUSE_END',
#  'SKILL_LEVEL_UP',
#  'TURRET_PLATE_DESTROYED',
#  'WARD_KILL',
#  'WARD_PLACED'}

# %%
pd.DataFrame(pd.DataFrame(timeline_data)['info'][4])['participantFrames']
# Out:
# 0     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 1     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 2     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 3     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 4     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 5     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 6     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 7     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 8     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 9     {'1': {'championStats': {'abilityHaste': 0, 'a...
# 10    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 11    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 12    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 13    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 14    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 15    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 16    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 17    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 18    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 19    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 20    {'1': {'championStats': {'abilityHaste': 0, 'a...
# 21    {'1': {'championStats': {'abilityHaste': 0, 'a...
# Name: participantFrames, dtype: object

# %%
def getcs(game):
    participants_15 = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(game)['info'][4])['participantFrames'][15])
    participants_15_df = participants_15.T[['participantId','jungleMinionsKilled','minionsKilled','level']]
    participants_15_df['cs'] = participants_15_df['jungleMinionsKilled'] + participants_15_df['minionsKilled']
    return participants_15_df['cs']

# %%
participants_15 = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(timeline_data)['info'][4])['participantFrames'][15])
participants_15
# Out:
#                                                                           1  \
# championStats             {'abilityHaste': 0, 'abilityPower': 0, 'armor'...
# currentGold                                                              73
# damageStats               {'magicDamageDone': 9839, 'magicDamageDoneToCh...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                       0
# level                                                                    11
# minionsKilled                                                           116
# participantId                                                             1
# position                                              {'x': 7976, 'y': 959}
# timeEnemySpentControlled                                              86631
# totalGold                                                              5723
# xp                                                                     7342
#
#                                                                           2  \
# championStats             {'abilityHaste': 0, 'abilityPower': 0, 'armor'...
# currentGold                                                            1077
# damageStats               {'magicDamageDone': 2730, 'magicDamageDoneToCh...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                       0
# level                                                                     9
# minionsKilled                                                            87
# participantId                                                             2
# position                                               {'x': 394, 'y': 461}
# timeEnemySpentControlled                                               7407
# totalGold                                                              4802
# xp                                                                     5691
#
#                                                                           3  \
# championStats             {'abilityHaste': 0, 'abilityPower': 119, 'armo...
# currentGold                                                             134
# damageStats               {'magicDamageDone': 45759, 'magicDamageDoneToC...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                      72
# level                                                                     9
# minionsKilled                                                             7
# participantId                                                             3
# position                                             {'x': 1422, 'y': 2131}
# timeEnemySpentControlled                                              73648
# totalGold                                                              6374
# xp                                                                     5159
#
#                                                                           4  \
# championStats             {'abilityHaste': 0, 'abilityPower': 0, 'armor'...
# currentGold                                                             170
# damageStats               {'magicDamageDone': 0, 'magicDamageDoneToChamp...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                       0
# level                                                                     8
# minionsKilled                                                            65
# participantId                                                             4
# position                                             {'x': 8414, 'y': 1490}
# timeEnemySpentControlled                                               2797
# totalGold                                                              5935
# xp                                                                     4227
#
#                                                                           5  \
# championStats             {'abilityHaste': 0, 'abilityPower': 204, 'armo...
# currentGold                                                              92
# damageStats               {'magicDamageDone': 7223, 'magicDamageDoneToCh...
# goldPerSecond                                                            30
# jungleMinionsKilled                                                       0
# level                                                                     8
# minionsKilled                                                            11
# participantId                                                             5
# position                                             {'x': 8414, 'y': 1490}
# timeEnemySpentControlled                                              24072
# totalGold                                                              5352
# xp                                                                     4623
#
#                                                                           6  \
# championStats             {'abilityHaste': 0, 'abilityPower': 18, 'armor...
# currentGold                                                             655
# damageStats               {'magicDamageDone': 23683, 'magicDamageDoneToC...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                       0
# level                                                                    11
# minionsKilled                                                           106
# participantId                                                             6
# position                                            {'x': 10015, 'y': 1673}
# timeEnemySpentControlled                                             369380
# totalGold                                                              5430
# xp                                                                     7699
#
#                                                                           7  \
# championStats             {'abilityHaste': 0, 'abilityPower': 0, 'armor'...
# currentGold                                                            1403
# damageStats               {'magicDamageDone': 24935, 'magicDamageDoneToC...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                      96
# level                                                                    10
# minionsKilled                                                             9
# participantId                                                             7
# position                                             {'x': 6093, 'y': 6402}
# timeEnemySpentControlled                                             209841
# totalGold                                                              7393
# xp                                                                     7193
#
#                                                                           8  \
# championStats             {'abilityHaste': 0, 'abilityPower': 163, 'armo...
# currentGold                                                            1779
# damageStats               {'magicDamageDone': 37668, 'magicDamageDoneToC...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                       0
# level                                                                    11
# minionsKilled                                                           100
# participantId                                                             8
# position                                            {'x': 11350, 'y': 1472}
# timeEnemySpentControlled                                             102666
# totalGold                                                              6849
# xp                                                                     7600
#
#                                                                           9  \
# championStats             {'abilityHaste': 0, 'abilityPower': 193, 'armo...
# currentGold                                                             354
# damageStats               {'magicDamageDone': 42407, 'magicDamageDoneToC...
# goldPerSecond                                                             0
# jungleMinionsKilled                                                       0
# level                                                                     9
# minionsKilled                                                            81
# participantId                                                             9
# position                                           {'x': 11338, 'y': 12972}
# timeEnemySpentControlled                                             122748
# totalGold                                                              7204
# xp                                                                     5345
#
#                                                                          10
# championStats             {'abilityHaste': 0, 'abilityPower': 0, 'armor'...
# currentGold                                                             254
# damageStats               {'magicDamageDone': 0, 'magicDamageDoneToChamp...
# goldPerSecond                                                            30
# jungleMinionsKilled                                                       0
# level                                                                     8
# minionsKilled                                                             9
# participantId                                                            10
# position                                           {'x': 11997, 'y': 11710}
# timeEnemySpentControlled                                             132609
# totalGold                                                              7003
# xp                                                                     4772

# %%
# time

# %%
def getlevel(game):
    participants_15 = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(game)['info'][4])['participantFrames'][15])
    participants_15_df = participants_15.T[['participantId','jungleMinionsKilled','minionsKilled','level']]
    return participants_15_df['level']

# %%
# participants_15 = pd.DataFrame.from_dict(pd.DataFrame(pd.DataFrame(timeline_data)['info'][4])['participantFrames'][15])

# %%
# participants_15_df = participants_15.T[['participantId','jungleMinionsKilled','minionsKilled','level']]
# participants_15_df['cs'] = participants_15_df['jungleMinionsKilled'] + participants_15_df['minionsKilled']
# participants_15_df

# %%
# def getELITE_MONSTER_KILL(game):
#     ELITE_MONSTER_KILL = []
#     for frame in game['info']['frames'][0:16]:
#         for event in frame['events']:
#             if event['type'] == 'ELITE_MONSTER_KILL':
#                 ELITE_MONSTER_KILL.append(event) 
#     ELITE_MONSTER_KILL = pd.DataFrame(ELITE_MONSTER_KILL)  
#     if len(ELITE_MONSTER_KILL.columns) >= 1:
#         return ELITE_MONSTER_KILL[['killerTeamId','monsterType']]
#     elif len(ELITE_MONSTER_KILL.columns) == 0:
#         return None
#     return ELITE_MONSTER_KILL[['killerTeamId','monsterType']]

# %%
getELITE_MONSTER_KILL(timeline_data)
# Out:
#    killerTeamId monsterType
# 0           100  RIFTHERALD
# 1           200      DRAGON

# %%
ELITE_MONSTER_KILL = []
def getELITE_MONSTER_KILL(game):
    ELITE_MONSTER_KILL = []
    for frame in game['info']['frames'][0:16]:
        for event in frame['events']:
            if event['type'] == 'ELITE_MONSTER_KILL':
                ELITE_MONSTER_KILL.append(event) 
    ELITE_MONSTER_KILL = pd.DataFrame(ELITE_MONSTER_KILL)                
    if 'monsterSubType' in ELITE_MONSTER_KILL.columns:
        return ELITE_MONSTER_KILL[['killerTeamId','monsterType', 'monsterSubType']]
    else:
        if len(ELITE_MONSTER_KILL.columns) >= 1:
            return ELITE_MONSTER_KILL[['killerTeamId','monsterType']]
        else:
            return None

# %%
ELITE_MONSTER_KILL = []
for frame in timeline_data['info']['frames'][0:16]:
    for event in frame['events']:
        if event['type'] == 'ELITE_MONSTER_KILL':
            ELITE_MONSTER_KILL.append(event) 
pd.DataFrame(ELITE_MONSTER_KILL)
# Out:
#    bounty  killerId  killerTeamId monsterType                 position  \
# 0       0         3           100  RIFTHERALD  {'x': 4856, 'y': 10236}
# 1       0         7           200      DRAGON   {'x': 9866, 'y': 4414}
#
#    timestamp                type assistingParticipantIds monsterSubType
# 0     601920  ELITE_MONSTER_KILL                     NaN            NaN
# 1     622760  ELITE_MONSTER_KILL                    [10]     AIR_DRAGON

# %%
getELITE_MONSTER_KILL(timeline_data)
# Out:
#    killerTeamId monsterType monsterSubType
# 0           100  RIFTHERALD            NaN
# 1           200      DRAGON     AIR_DRAGON

# %%
# def getELITE_MONSTER_KILL(game):
#     ELITE_MONSTER_KILL = []
#     for frame in game['info']['frames'][0:16]:
#         for event in frame['events']:
#             if event['type'] == 'ELITE_MONSTER_KILL':
#                 ELITE_MONSTER_KILL.append(event) 
#     ELITE_MONSTER_KILL = pd.DataFrame(ELITE_MONSTER_KILL)                
#     if len(ELITE_MONSTER_KILL.columns) == 9:
#         return ELITE_MONSTER_KILL[['killerTeamId','monsterType', 'monsterSubType']]
#     elif len(ELITE_MONSTER_KILL.columns) == 8:
#         return ELITE_MONSTER_KILL[['killerTeamId','monsterType']]
#     elif len(ELITE_MONSTER_KILL.columns) == 7:
#         return ELITE_MONSTER_KILL[['killerTeamId','monsterType']]
#     elif len(ELITE_MONSTER_KILL.columns) == 0:
#         return NONE

# %%
getELITE_MONSTER_KILL(timeline_data)
# Out:
#    killerTeamId monsterType
# 0           100  RIFTHERALD
# 1           200      DRAGON

# %%
matchdata = lol_watcher.match.by_id(region= player_routing, match_id= 'NA1_4286751232')

# %%
pd.DataFrame(matchdata)['info'][15]
# Out:
# [{'bans': [{'championId': 221, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 498, 'pickTurn': 3},
#    {'championId': 154, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}],
#   'objectives': {'baron': {'first': False, 'kills': 2},
#    'champion': {'first': True, 'kills': 44},
#    'dragon': {'first': False, 'kills': 4},
#    'inhibitor': {'first': True, 'kills': 4},
#    'riftHerald': {'first': True, 'kills': 1},
#    'tower': {'first': True, 'kills': 10}},
#   'teamId': 100,
#   'win': True},
#  {'bans': [{'championId': 107, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 104, 'pickTurn': 8},
#    {'championId': 114, 'pickTurn': 9},
#    {'championId': 203, 'pickTurn': 10}],
#   'objectives': {'baron': {'first': True, 'kills': 1},
#    'champion': {'first': False, 'kills': 28},
#    'dragon': {'first': True, 'kills': 2},
#    'inhibitor': {'first': False, 'kills': 0},
#    'riftHerald': {'first': False, 'kills': 1},
#    'tower': {'first': False, 'kills': 2}},
#   'teamId': 200,
#   'win': False}]

# %%
pd.DataFrame(matchdata)['info'][15][0]['win']
# Out:
# True

# %%
def getwin(game):
    getoutcome = {}
    for outcome in pd.DataFrame(game)['info'][15]:
        if outcome['win'] == True:
             getoutcome.update({outcome['teamId']:outcome['win']})
    return getoutcome
getwin(matchdata)
# Out:
# {100: True}

# %%
len(pd.DataFrame(pd.DataFrame(timeline_data)['info'][4])['participantFrames'])
# Out:
# 22

# %%
gamedist= []

for game in unique_matchIDs[0:100]:
    timeline = lol_watcher.match.timeline_by_match(region= player_routing, match_id= game)
    length = len(pd.DataFrame(pd.DataFrame(timeline)['info'][4])['participantFrames'])
    gamedist.append(length)

# %%
a_gamedist = np.array(gamedist)
a_gamedist
# Out:
# array([26, 22, 30, 28, 23, 39, 26, 21, 30, 25, 27, 28, 28, 25, 29, 28, 27,
#        25, 32, 25, 23, 17, 17, 32, 26, 23, 17, 24, 31, 31, 35, 32, 30,  5,
#        30, 36, 19, 20, 32, 22, 31, 20, 30, 33, 33, 27, 37, 28, 17, 29, 33,
#        24, 23, 27, 27, 23, 18, 24, 31, 20, 26, 31, 31, 30, 29, 25, 27, 33,
#        29, 28, 25, 22, 42, 21, 32, 20, 23, 38, 26, 26, 33, 32, 28, 24, 29,
#        33, 32, 25, 29, 33, 23, 22, 36, 28, 21, 21, 27, 30, 25, 33])

# %%
gameInformationList = []

for game in unique_matchIDs[0:100]:
    timeline = lol_watcher.match.timeline_by_match(region= player_routing, match_id= game)
    matchdata = lol_watcher.match.by_id(region= player_routing, match_id= game)
    
    if len(pd.DataFrame(pd.DataFrame(timeline)['info'][4])['participantFrames']) >= 16:
        gameInformation = {}
        gameInformation['kills'] = getKills(timeline)
        gameInformation['visionScore'] = getVisionScore(timeline)
        gameInformation['assists'] = getAssists(timeline)
        gameInformation['cs'] = getcs(timeline)
        gameInformation['level'] = getlevel(timeline)
        gameInformation['Epic_Monsters'] = getELITE_MONSTER_KILL(timeline)
        gameInformation['Win'] = getwin(matchdata)
        gameInformationList.append(gameInformation)
    else:
        pass
            
pd.DataFrame(gameInformationList)
# Out:
#                                                 kills  \
# 0             victimId
# killerId
# 0       ...
# 1             victimId
# killerId
# 1       ...
# 2             victimId
# killerId
# 1       ...
# 3             victimId
# killerId
# 1       ...
# 4             victimId
# killerId
# 1       ...
# ..                                                ...
# 94            victimId
# killerId
# 2       ...
# 95            victimId
# killerId
# 1       ...
# 96            victimId
# killerId
# 1       ...
# 97            victimId
# killerId
# 1       ...
# 98            victimId
# killerId
# 1       ...
#
#                                           visionScore  \
# 0       VisionScore
# 1           7.0
# 2           3....
# 1       VisionScore
# 1           2.0
# 2           4....
# 2       VisionScore
# 1           6.0
# 2           2....
# 3       VisionScore
# 1           6.0
# 2           5....
# 4       VisionScore
# 1           7.0
# 2           7....
# ..                                                ...
# 94      VisionScore
# 1           6.0
# 2           4....
# 95      VisionScore
# 1           4.0
# 2           7....
# 96      VisionScore
# 1           6.0
# 2           2....
# 97      VisionScore
# 1           5.0
# 2           6....
# 98      VisionScore
# 1           4.0
# 2           8....
#
#                                               assists  \
# 0   {1: 5, 2: 4, 6: 1, 5: 3, 10: 1, 7: 2, 3: 1, 4:...
# 1   {7: 5, 1: 3, 9: 7, 4: 6, 10: 6, 8: 6, 2: 5, 3:...
# 2   {9: 3, 10: 4, 7: 1, 5: 1, 1: 2, 2: 3, 3: 1, 8: 1}
# 3   {6: 3, 8: 8, 9: 6, 10: 4, 4: 1, 5: 5, 2: 2, 3: 1}
# 4   {4: 4, 2: 7, 5: 8, 1: 4, 10: 5, 3: 4, 8: 1, 9:...
# ..                                                ...
# 94  {10: 1, 2: 2, 3: 2, 4: 4, 7: 1, 8: 1, 9: 2, 5: 2}
# 95  {6: 6, 7: 2, 10: 6, 1: 2, 2: 3, 4: 1, 9: 2, 8:...
# 96  {5: 6, 10: 6, 1: 1, 9: 4, 7: 1, 2: 3, 8: 1, 4: 1}
# 97       {5: 10, 9: 3, 10: 5, 4: 4, 2: 2, 3: 1, 8: 2}
# 98        {2: 5, 4: 4, 5: 6, 3: 6, 9: 1, 10: 1, 7: 1}
#
#                                                    cs  \
# 0   1     123
# 2      95
# 3     100
# 4     129
# 5     ...
# 1   1     116
# 2      87
# 3      79
# 4      65
# 5     ...
# 2   1     122
# 2     134
# 3      75
# 4     124
# 5     ...
# 3   1      99
# 2     102
# 3     106
# 4      97
# 5     ...
# 4   1     136
# 2     113
# 3      78
# 4     110
# 5     ...
# ..                                                ...
# 94  1     101
# 2      81
# 3      81
# 4     130
# 5     ...
# 95  1      86
# 2      77
# 3     123
# 4      81
# 5     ...
# 96  1     124
# 2     126
# 3     114
# 4      67
# 5     ...
# 97  1     117
# 2      81
# 3     149
# 4      92
# 5     ...
# 98  1     137
# 2      86
# 3     103
# 4     107
# 5     ...
#
#                                                 level  \
# 0   1     11
# 2     10
# 3     10
# 4      9
# 5      7
# 6...
# 1   1     11
# 2      9
# 3      9
# 4      8
# 5      8
# 6...
# 2   1     11
# 2     11
# 3      9
# 4      9
# 5      7
# 6...
# 3   1     10
# 2      9
# 3     10
# 4      8
# 5      7
# 6...
# 4   1     12
# 2     11
# 3     10
# 4      9
# 5      8
# 6...
# ..                                                ...
# 94  1     10
# 2      9
# 3     10
# 4      9
# 5      8
# 6...
# 95  1     10
# 2      9
# 3     10
# 4      9
# 5      8
# 6...
# 96  1     10
# 2     11
# 3     10
# 4      7
# 5      8
# 6...
# 97  1     10
# 2      9
# 3     11
# 4     10
# 5      7
# 6...
# 98  1     11
# 2      9
# 3     10
# 4      9
# 5      7
# 6...
#
#                                         Epic_Monsters          Win
# 0      killerTeamId monsterType  monsterSubType
# 0 ...  {100: True}
# 1      killerTeamId monsterType monsterSubType
# 0  ...  {200: True}
# 2      killerTeamId monsterType  monsterSubType
# 0 ...  {200: True}
# 3      killerTeamId monsterType monsterSubType
# 0  ...  {200: True}
# 4      killerTeamId monsterType monsterSubType
# 0  ...  {100: True}
# ..                                                ...          ...
# 94     killerTeamId monsterType  monsterSubType
# 0 ...  {200: True}
# 95     killerTeamId monsterType monsterSubType
# 0  ...  {200: True}
# 96     killerTeamId monsterType monsterSubType
# 0  ...  {100: True}
# 97     killerTeamId monsterType  monsterSubType
# 0 ...  {200: True}
# 98     killerTeamId monsterType  monsterSubType
# 0 ...  {100: True}
#
# [99 rows x 7 columns]

# %%
gameInformationList = []

for game in gamesDataRaw
    participantId = getParticipantIdFromAccountId(game, accountID)
    teamId, ChampionId, win = getTreamAndChamption(game, participantID)
    compositions = getTeamComposition(game)
    
    gameInformation = {}
    gameInformation['win'] = win
    gameInformation ['visionScore'] = participantD[visionScore]
    gameInformation['champion'] = championIdToName[championID]
    gameInformation['patch'] = getPatch(game)
    gameInformation['date'] = getDate(game)
    gameInformation['teamComposition'] = "/".join([championIdToName[chld] for chld in compositions[teamId]])
    gameInformation['enemyTeamComposition'] = "/".join([championIdToName[chld] for chld in compositions[100 if teamId==200 else 200]])
    
    gameInformationList.append(gameInformation)

gameInformationList

# %%
# arg = lol_watcher.match.timeline_by_match(region='americas', match_id='NA1_4301968712')

# %%
# def getELITE_MONSTER_KILL(game):
#     ELITE_MONSTER_KILL = []
#     for frame in game['info']['frames'][0:16]:
#         for event in frame['events']:
#             if event['type'] == 'ELITE_MONSTER_KILL':
#                 ELITE_MONSTER_KILL.append(event) 
#     ELITE_MONSTER_KILL = pd.DataFrame(ELITE_MONSTER_KILL)            
#     return ELITE_MONSTER_KILL

# %%
# sum(getELITE_MONSTER_KILL(arg).columns.str.contains('monsterType'))
# Out:
# 1

# %%
# def getELITE_MONSTER_KILL(game):
#     ELITE_MONSTER_KILL = []
#     for frame in game['info']['frames'][0:16]:
#         for event in frame['events']:
#             if event['type'] == 'ELITE_MONSTER_KILL':
#                 ELITE_MONSTER_KILL.append(event) 
#     ELITE_MONSTER_KILL = pd.DataFrame(ELITE_MONSTER_KILL)                
#     if sum(getELITE_MONSTER_KILL(arg).columns.str.contains('monsterSubType')) == 1:
#         return ELITE_MONSTER_KILL[['killerTeamId','monsterType', 'monsterSubType']]
#     elif sum(getELITE_MONSTER_KILL(arg).columns.str.contains('monsterSubType')) == 0:
#         return ELITE_MONSTER_KILL[['killerTeamId','monsterType']]

# %%
# match_data_big = []
# for match in unique_matchIDs:
#     match_data_big.append(lol_watcher.match.timeline_by_match(region= player_routing, match_id= match))

# %%
# match_data_time = [lol_watcher.match.timeline_by_match(region= player_routing, match_id= match) for match in unique_matchIDs]
